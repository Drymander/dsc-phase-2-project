# %% [markdown]
# # Final Project Submission

# %% [markdown]
# Please fill out:
# * Student name: Johnny Dryman
# * Student pace: full time
# * Scheduled project review date/time: TBD
# * Instructor name: James Irving
# * Blog post URL: TBD

# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# > For the Phase 2 Project, we will be analyzing housing sales data for King County (Seattle, WA area).  We will be using multivariate linear regression to explore which features of the data have the greatest influence on price.
#
# ## Business Problem
#
# As home values continue to sky rocket in the pandemic era, many King County residents have inquired about how to increase the value of their homes.  Fortunately, we have access to all homes sold in King County for roughly one year, from May 2014 - May 2015.
#
# This data gives us access to a variety of important metrics both quantitative and somewhat qualitative.
#
# After scrubbing the data and assuring quality, we will use multivariate linear regression to analyze our features and determine their relationship with sale price.
#
# Finally, we will formulate our observations into useful recommendations to any home owner interested in improving their value.

# %% [markdown]
# # OBTAIN

# %% [markdown]
# We will begin by importing our packages for data exploration and load our .csv data into a pandas dataframe.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('data/kc_house_data.csv')

df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# # SCRUB

# %% [markdown]
# ## Data Preparation
#
# We'll begin by getting a brief overview of our data and check for null values.

# %%
df.head()

print(df.info())

print(df.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
#  17  lat            21597 non-null  float64
#  18  long           21597 non-null  float64
#  19  sqft_living15  21597 non-null  int64
#  20  sqft_lot15     21597 non-null  int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB
# None
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
df = df.set_index('id')

# %% [markdown]
# Using missingno package to visualize null values.

# %%
import missingno as msno

msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Creating clean_column function, which will help us look at unique items.  This will be useful for identifying any data that seems off or incorrect.

# %%
def clean_column(column, unique_count=10):
    column_str = str(column)
    print('Datatype: ' + str(df[column].dtypes))
    print('Total unique itms: ' + str(df[column].nunique()))
    print('Displaying first ' + str(unique_count) + ':')
    print(df[column].unique()[0:unique_count])
    return column_str

def null_count(df):
    print('---Total Entries---')
    print(df.describe())
    print('---Non-Null Values---')
    print(df.notna().describe())

# %% [markdown]
# Let's take a look at our features that have null values.

# %% [markdown]
# We could conceivably estimate our null values, and that might be interesting for further analysis.  Mapping could be used with 'latitude' and 'longitude' and potentially calculate distance to water.  However, for this project, our safest bet will be to drop the null values.

# %%
null_count(df['waterfront'])
# Out:
# ---Total Entries---
# count   19221.00
# mean        0.01
# std         0.09
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max         1.00
# Name: waterfront, dtype: float64
# ---Non-Null Values---
# count     21597
# unique        2
# top        True
# freq      19221
# Name: waterfront, dtype: object

# %%
clean_column('waterfront')

df = df[df['waterfront'].notna()]

clean_column('waterfront')
# Out:
# Datatype: float64
# Total unique itms: 2
# Displaying first 10:
# [nan  0.  1.]
# Datatype: float64
# Total unique itms: 2
# Displaying first 10:
# [0. 1.]
# 'waterfront'

# %% [markdown]
# View has very few null values, it is safe to remove them from the dataset.

# %%
null_count(df['view'])
# Out:
# ---Total Entries---
# count   19164.00
# mean        0.23
# std         0.76
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max         4.00
# Name: view, dtype: float64
# ---Non-Null Values---
# count     19221
# unique        2
# top        True
# freq      19164
# Name: view, dtype: object

# %%
clean_column('view')

df = df[df['view'].notna()]

clean_column('view')
# Out:
# Datatype: float64
# Total unique itms: 5
# Displaying first 10:
# [ 0. nan  3.  4.  2.  1.]
# Datatype: float64
# Total unique itms: 5
# Displaying first 10:
# [0. 3. 4. 2. 1.]
# 'view'

# %% [markdown]
# Yr_renovated has ~3,500 null values.  We would want to consider removing the column in this case, but yr_renovated indicates a renovation occurred with a year (e.g. 2007) and a renovation has never occurred with a zero (e.g. 0).  The null values could also represent houses that have never been renovated, but we can't be sure.

# %%
null_count(df['yr_renovated'])
# Out:
# ---Total Entries---
# count   15762.00
# mean       82.44
# std       397.21
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max      2015.00
# Name: yr_renovated, dtype: float64
# ---Non-Null Values---
# count     19164
# unique        2
# top        True
# freq      15762
# Name: yr_renovated, dtype: object

# %%
clean_column('yr_renovated', unique_count=115)
# Out:
# Datatype: float64
# Total unique itms: 70
# Displaying first 115:
# [1991.   nan    0. 2002. 2010. 1992. 2013. 1994. 1978. 2005. 2003. 1984.
#  1954. 2014. 2011. 1983. 1990. 1988. 1977. 1981. 1995. 2000. 1999. 1998.
#  1970. 1989. 2004. 1986. 2007. 1987. 2006. 1985. 2001. 1980. 1971. 1945.
#  1979. 1997. 1950. 1969. 1948. 2009. 2015. 2008. 2012. 1968. 1963. 1951.
#  1962. 1953. 1993. 1955. 1996. 1982. 1956. 1940. 1976. 1946. 1975. 1964.
#  1973. 1957. 1959. 1960. 1965. 1967. 1934. 1972. 1944. 1958. 1974.]
# 'yr_renovated'

# %% [markdown]
# We will first remove rows with nan values from the dataset.

# %%
df = df[df['yr_renovated'].notna()]

df.describe()
# Out:
#            price  bedrooms  bathrooms  sqft_living   sqft_lot   floors  \
# count   15762.00  15762.00   15762.00     15762.00   15762.00 15762.00
# mean   541317.18      3.38       2.12      2084.51   15280.82     1.50
# std    372225.84      0.94       0.77       918.62   41822.88     0.54
# min     82000.00      1.00       0.50       370.00     520.00     1.00
# 25%    321000.00      3.00       1.75      1430.00    5048.50     1.00
# 50%    450000.00      3.00       2.25      1920.00    7602.00     1.50
# 75%    644875.00      4.00       2.50      2550.00   10720.00     2.00
# max   7700000.00     33.00       8.00     13540.00 1651359.00     3.50
#
#        waterfront     view  condition    grade  sqft_above  yr_built  \
# count    15762.00 15762.00   15762.00 15762.00    15762.00  15762.00
# mean         0.01     0.23       3.41     7.66     1792.78   1971.11
# std          0.09     0.76       0.65     1.17      828.40     29.34
# min          0.00     0.00       1.00     3.00      370.00   1900.00
# 25%          0.00     0.00       3.00     7.00     1200.00   1952.00
# 50%          0.00     0.00       3.00     7.00     1570.00   1975.00
# 75%          0.00     0.00       4.00     8.00     2220.00   1997.00
# max          1.00     4.00       5.00    13.00     9410.00   2015.00
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# count      15762.00 15762.00 15762.00 15762.00       15762.00    15762.00
# mean          82.44 98077.56    47.56  -122.21        1990.22    12900.42
# std          397.21    53.41     0.14     0.14         684.14    27977.23
# min            0.00 98001.00    47.16  -122.52         399.00      659.00
# 25%            0.00 98033.00    47.47  -122.33        1490.00     5100.00
# 50%            0.00 98065.00    47.57  -122.23        1846.00     7620.00
# 75%            0.00 98117.00    47.68  -122.12        2370.00    10107.50
# max         2015.00 98199.00    47.78  -121.31        6210.00   871200.00

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
ren_df = df[df['yr_renovated'] != 0]

not_ren_df = df[df['yr_renovated'] == 0]

# %%
ren_df['price'].describe()
# Out:
# count       651.00
# mean     760872.06
# std      637150.64
# min      110000.00
# 25%      410000.00
# 50%      600000.00
# 75%      886250.00
# max     7700000.00
# Name: price, dtype: float64

# %%
not_ren_df['price'].describe()
# Out:
# count     15111.00
# mean     531858.49
# std      353400.02
# min       82000.00
# 25%      320000.00
# 50%      449000.00
# 75%      633000.00
# max     6890000.00
# Name: price, dtype: float64

# %% [markdown]
# The means, standard deviations, and medians for renovated and non-renovated houses are significant.  We will revisit yr_renovated and potentially convert the column to a binary value.

# %% [markdown]
# Checking non-nulls again.

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Now we'll take a look at each column and see if anything needs correction.

# %% [markdown]
# ## Feature Review

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15762 entries, 6414100192 to 1523300157
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           15762 non-null  object
#  1   price          15762 non-null  float64
#  2   bedrooms       15762 non-null  int64
#  3   bathrooms      15762 non-null  float64
#  4   sqft_living    15762 non-null  int64
#  5   sqft_lot       15762 non-null  int64
#  6   floors         15762 non-null  float64
#  7   waterfront     15762 non-null  float64
#  8   view           15762 non-null  float64
#  9   condition      15762 non-null  int64
#  10  grade          15762 non-null  int64
#  11  sqft_above     15762 non-null  int64
#  12  sqft_basement  15762 non-null  object
#  13  yr_built       15762 non-null  int64
#  14  yr_renovated   15762 non-null  float64
#  15  zipcode        15762 non-null  int64
#  16  lat            15762 non-null  float64
#  17  long           15762 non-null  float64
#  18  sqft_living15  15762 non-null  int64
#  19  sqft_lot15     15762 non-null  int64
# dtypes: float64(8), int64(10), object(2)
# memory usage: 2.5+ MB
# None

# %% [markdown]
# We will define a few functions to more efficiently analyze individual features.

# %%
def clean_column(column, unique_count=10):
    column_str = str(column)
    print('Datatype: ' + str(df[column].dtypes))
    print('Total unique itms: ' + str(df[column].nunique()))
    print('Displaying first ' + str(unique_count) + ':')
    print(df[column].unique()[0:unique_count])
    print(f"Minimum value: {df[column].min()}.  Maximum value: {df[column].max()}")
    print(df[column].describe())
    return column_str

def regplot(column, df=df):
    return sns.regplot(data=df, x=column, y='price')
    
def hist(column):
    hist = df[column].hist()
    return plt.show()

def displot(column):
    return sns.displot(data=df, x=column, y='price')

# %% [markdown]
# ### Price

# %% [markdown]
# ### Date

# %%
df['date'] = df['date'].apply(pd.to_datetime)

# %%
clean_column('date')

df['bedrooms'].describe()
# Out:
# Datatype: datetime64[ns]
# Total unique itms: 369
# Displaying first 10:
# ['2014-12-09T00:00:00.000000000' '2015-02-18T00:00:00.000000000'
#  '2014-05-12T00:00:00.000000000' '2014-06-27T00:00:00.000000000'
#  '2015-04-15T00:00:00.000000000' '2015-03-12T00:00:00.000000000'
#  '2014-05-27T00:00:00.000000000' '2014-10-07T00:00:00.000000000'
#  '2015-01-24T00:00:00.000000000' '2014-07-31T00:00:00.000000000']
# Minimum value: 2014-05-02 00:00:00.  Maximum value: 2015-05-27 00:00:00
# count                   15762
# unique                    369
# top       2014-06-25 00:00:00
# freq                      103
# first     2014-05-02 00:00:00
# last      2015-05-27 00:00:00
# Name: date, dtype: object
# <ipython-input-595-17aaff753c74>:8: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(df[column].describe())
# count   15762.00
# mean        3.38
# std         0.94
# min         1.00
# 25%         3.00
# 50%         3.00
# 75%         4.00
# max        33.00
# Name: bedrooms, dtype: float64

# %%
df['date'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Bedrooms

# %%
clean_column('bedrooms', unique_count=20)
# Out:
# Datatype: int64
# Total unique itms: 12
# Displaying first 20:
# [ 3  4  2  5  1  6  7  8  9 11 10 33]
# Minimum value: 1.  Maximum value: 33
# count   15762.00
# mean        3.38
# std         0.94
# min         1.00
# 25%         3.00
# 50%         3.00
# 75%         4.00
# max        33.00
# Name: bedrooms, dtype: float64
# 'bedrooms'

# %%
displot('bedrooms')

# %%
df.loc[df['bedrooms'] == 33]
# Out:
#                  date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 2402100895 2014-06-25 640000.00        33       1.75         1620      6000
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 2402100895    1.00        0.00  0.00          5      7        1040
#
#            sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# id
# 2402100895         580.0      1947          0.00    98103 47.69 -122.33
#
#             sqft_living15  sqft_lot15
# id
# 2402100895           1330        4700

# %% [markdown]
# Based on other stats, we assume the one entry with 33 bedrooms to actually be 3 bedrooms.  Correcting below.

# %%
df['bedrooms'] = df['bedrooms'].replace([33],3)

df.loc[df['bedrooms'] == 33]
# Out:
# Empty DataFrame
# Columns: [date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []

# %%
df.loc[df['bedrooms'] == 11]
# Out:
#                  date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 1773100755 2014-08-21 520000.00        11       3.00         3000      4960
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 1773100755    2.00        0.00  0.00          3      7        2400
#
#            sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# id
# 1773100755         600.0      1918       1999.00    98106 47.56 -122.36
#
#             sqft_living15  sqft_lot15
# id
# 1773100755           1420        4960

# %% [markdown]
# The 11 bedroom house also seems unlikely based on square footage.  Googling the ID '1773100755' revelas it to be a 4 bedroom house.

# %%
df['bedrooms'] = df['bedrooms'].replace([11],4)

df.loc[df['bedrooms'] == 11]
# Out:
# Empty DataFrame
# Columns: [date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []

# %%
df.loc[df['bedrooms'] == 10]
# Out:
#                  date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 627300145  2014-08-14 1150000.00        10       5.25         4590     10920
# 5566100170 2014-10-29  650000.00        10       2.00         3610     11914
# 8812401450 2014-12-29  660000.00        10       3.00         2920      3745
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 627300145     1.00        0.00  2.00          3      9        2500
# 5566100170    2.00        0.00  0.00          4      7        3010
# 8812401450    2.00        0.00  0.00          4      7        1860
#
#            sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# id
# 627300145         2090.0      2008          0.00    98004 47.59 -122.11
# 5566100170         600.0      1958          0.00    98006 47.57 -122.17
# 8812401450        1060.0      1913          0.00    98105 47.66 -122.32
#
#             sqft_living15  sqft_lot15
# id
# 627300145            2730       10400
# 5566100170           2040       11914
# 8812401450           1810        3745

# %% [markdown]
# Even though two of the 10 bedroom houses seem unlikely, a quick google shows that they are recorded as 9 bedroom houses on zillow.  We will assume these entries were accurate at the time, and will not change.

# %% [markdown]
# ### Bathrooms

# %%
clean_column('bathrooms', unique_count=29)
# Out:
# Datatype: float64
# Total unique itms: 27
# Displaying first 29:
# [2.25 3.   2.   4.5  1.   2.5  1.75 2.75 1.5  3.25 4.   3.5  0.75 5.
#  4.25 3.75 1.25 5.25 4.75 0.5  5.5  6.   5.75 8.   6.75 7.5  7.75]
# Minimum value: 0.5.  Maximum value: 8.0
# count   15762.00
# mean        2.12
# std         0.77
# min         0.50
# 25%         1.75
# 50%         2.25
# 75%         2.50
# max         8.00
# Name: bathrooms, dtype: float64
# 'bathrooms'

# %%
hist('bathrooms')

# %%
regplot('bathrooms')
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='price'>

# %% [markdown]
# ### Squarefoot - Living

# %%
clean_column('sqft_living')
# Out:
# Datatype: int64
# Total unique itms: 912
# Displaying first 10:
# [2570 1960 1680 5420 1715 1780 1890 1160 1370 1810]
# Minimum value: 370.  Maximum value: 13540
# count   15762.00
# mean     2084.51
# std       918.62
# min       370.00
# 25%      1430.00
# 50%      1920.00
# 75%      2550.00
# max     13540.00
# Name: sqft_living, dtype: float64
# 'sqft_living'

# %%
regplot('sqft_living')
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
hist('sqft_living')

# %% [markdown]
# There seem to be at least one unusual outlier for the price.  We will want to take a look at the largest values to verify the quality of the data.

# %%
df.sort_values(by=['sqft_living'], ascending=False).head(5)
# Out:
#                  date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 1225069038 2014-05-05 2280000.00         7       8.00        13540    307752
# 6762700020 2014-10-13 7700000.00         6       8.00        12050     27600
# 9808700762 2014-06-11 7060000.00         5       4.50        10040     37325
# 9208900037 2014-09-19 6890000.00         6       7.75         9890     31374
# 1924059029 2014-06-17 4670000.00         5       6.75         9640     13068
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 1225069038    3.00        0.00  4.00          3     12        9410
# 6762700020    2.50        0.00  3.00          4     13        8570
# 9808700762    2.00        1.00  2.00          3     11        7680
# 9208900037    2.00        0.00  4.00          3     13        8860
# 1924059029    1.00        1.00  4.00          3     12        4820
#
#            sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# id
# 1225069038        4130.0      1999          0.00    98053 47.67 -121.99
# 6762700020        3480.0      1910       1987.00    98102 47.63 -122.32
# 9808700762        2360.0      1940       2001.00    98004 47.65 -122.21
# 9208900037        1030.0      2001          0.00    98039 47.63 -122.24
# 1924059029        4820.0      1983       2009.00    98040 47.56 -122.21
#
#             sqft_living15  sqft_lot15
# id
# 1225069038           4850      217800
# 6762700020           3940        8800
# 9808700762           3930       25449
# 9208900037           4540       42730
# 1924059029           3270       10454

# %% [markdown]
# After reviewing the one outlier, it seems to be a compound in a rural area, and the sqft seems realistic.

# %% [markdown]
# ### Squarefoot - Lot

# %%
clean_column('sqft_lot')
regplot('sqft_lot')
# Out:
# Datatype: int64
# Total unique itms: 7927
# Displaying first 10:
# [  7242   5000   8080 101930   6819   7470   6560   6000   9680   4850]
# Minimum value: 520.  Maximum value: 1651359
# count     15762.00
# mean      15280.82
# std       41822.88
# min         520.00
# 25%        5048.50
# 50%        7602.00
# 75%       10720.00
# max     1651359.00
# Name: sqft_lot, dtype: float64
# <AxesSubplot:xlabel='sqft_lot', ylabel='price'>

# %%
hist('sqft_lot')

# %%
df.sort_values(by=['sqft_lot'], ascending=False).head(5)

#outlier looks like a farm, will keep
# Out:
#                  date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 1020069017 2015-03-27 700000.00         4       1.00         1300   1651359
# 3326079016 2015-05-04 190000.00         2       1.00          710   1164794
# 2323089009 2015-01-19 855000.00         4       3.50         4030   1024068
# 722069232  2014-09-05 998000.00         4       3.25         3770    982998
# 3626079040 2014-07-30 790000.00         2       3.00         2560    982278
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 1020069017    1.00        0.00  3.00          4      6        1300
# 3326079016    1.00        0.00  0.00          2      5         710
# 2323089009    2.00        0.00  0.00          3     10        4030
# 722069232     2.00        0.00  0.00          3     10        3770
# 3626079040    1.00        0.00  0.00          3      8        2560
#
#            sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# id
# 1020069017           0.0      1920          0.00    98022 47.23 -122.02
# 3326079016           0.0      1915          0.00    98014 47.69 -121.91
# 2323089009           0.0      2006          0.00    98045 47.46 -121.74
# 722069232            0.0      1992          0.00    98058 47.41 -122.09
# 3626079040           0.0      2004          0.00    98014 47.70 -121.86
#
#             sqft_living15  sqft_lot15
# id
# 1020069017           2560      425581
# 3326079016           1680       16730
# 2323089009           1830       11700
# 722069232            2290       37141
# 3626079040           1620       40946

# %% [markdown]
# ### Floors

# %%
clean_column('floors')

regplot('floors')
# Out:
# Datatype: float64
# Total unique itms: 6
# Displaying first 10:
# [2.  1.  1.5 3.  2.5 3.5]
# Minimum value: 1.0.  Maximum value: 3.5
# count   15762.00
# mean        1.50
# std         0.54
# min         1.00
# 25%         1.00
# 50%         1.50
# 75%         2.00
# max         3.50
# Name: floors, dtype: float64
# <AxesSubplot:xlabel='floors', ylabel='price'>

# %%
hist('floors')

# %% [markdown]
# ### Waterfront

# %%
clean_column('waterfront')

regplot('waterfront')
# Out:
# Datatype: float64
# Total unique itms: 2
# Displaying first 10:
# [0. 1.]
# Minimum value: 0.0.  Maximum value: 1.0
# count   15762.00
# mean        0.01
# std         0.09
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max         1.00
# Name: waterfront, dtype: float64
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
hist('waterfront')

# %% [markdown]
# ### View

# %%
clean_column('view')

regplot('view')
# Out:
# Datatype: float64
# Total unique itms: 5
# Displaying first 10:
# [0. 3. 4. 2. 1.]
# Minimum value: 0.0.  Maximum value: 4.0
# count   15762.00
# mean        0.23
# std         0.76
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max         4.00
# Name: view, dtype: float64
# <AxesSubplot:xlabel='view', ylabel='price'>

# %% [markdown]
# ### Condition

# %%
clean_column('condition')

regplot('condition')
# Out:
# Datatype: int64
# Total unique itms: 5
# Displaying first 10:
# [3 5 4 1 2]
# Minimum value: 1.  Maximum value: 5
# count   15762.00
# mean        3.41
# std         0.65
# min         1.00
# 25%         3.00
# 50%         3.00
# 75%         4.00
# max         5.00
# Name: condition, dtype: float64
# <AxesSubplot:xlabel='condition', ylabel='price'>

# %%
hist('condition')

# %% [markdown]
# ### Grade

# %%
clean_column('grade')

regplot('grade')
# Out:
# Datatype: int64
# Total unique itms: 11
# Displaying first 10:
# [ 7  8 11  9  6  5 10 12  4  3]
# Minimum value: 3.  Maximum value: 13
# count   15762.00
# mean        7.66
# std         1.17
# min         3.00
# 25%         7.00
# 50%         7.00
# 75%         8.00
# max        13.00
# Name: grade, dtype: float64
# <AxesSubplot:xlabel='grade', ylabel='price'>

# %%
hist('grade')

# %%
df[df['grade'] == 13]
# Out:
#                  date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 9831200500 2015-03-04 2480000.00         5       3.75         6810      7500
# 7237501190 2014-10-10 1780000.00         4       3.25         4890     13402
# 1725059316 2014-11-20 2390000.00         4       4.00         6330     13296
# 853200010  2014-07-01 3800000.00         5       5.50         7050     42840
# 6762700020 2014-10-13 7700000.00         6       8.00        12050     27600
# 1068000375 2014-09-23 3200000.00         6       5.00         7100     18200
# 9208900037 2014-09-19 6890000.00         6       7.75         9890     31374
# 3303850390 2014-12-12 2980000.00         5       5.50         7400     18898
# 2426039123 2015-01-30 2420000.00         5       4.75         7880     24250
# 4139900180 2015-04-20 2340000.00         4       2.50         4500     35200
# 2303900100 2014-09-11 3800000.00         3       4.25         5510     35000
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 9831200500    2.50        0.00  0.00          3     13        6110
# 7237501190    2.00        0.00  0.00          3     13        4890
# 1725059316    2.00        0.00  2.00          3     13        4900
# 853200010     1.00        0.00  2.00          4     13        4320
# 6762700020    2.50        0.00  3.00          4     13        8570
# 1068000375    2.50        0.00  0.00          3     13        5240
# 9208900037    2.00        0.00  4.00          3     13        8860
# 3303850390    2.00        0.00  3.00          3     13        6290
# 2426039123    2.00        0.00  2.00          3     13        7880
# 4139900180    1.00        0.00  0.00          3     13        4500
# 2303900100    2.00        0.00  4.00          3     13        4910
#
#            sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# id
# 9831200500         700.0      1922          0.00    98102 47.63 -122.32
# 7237501190           0.0      2004          0.00    98059 47.53 -122.13
# 1725059316        1430.0      2000          0.00    98033 47.65 -122.20
# 853200010         2730.0      1978          0.00    98004 47.62 -122.22
# 6762700020        3480.0      1910       1987.00    98102 47.63 -122.32
# 1068000375        1860.0      1933       2002.00    98199 47.64 -122.41
# 9208900037        1030.0      2001          0.00    98039 47.63 -122.24
# 3303850390        1110.0      2001          0.00    98006 47.54 -122.11
# 2426039123           0.0      1996          0.00    98177 47.73 -122.36
# 4139900180           0.0      1988          0.00    98006 47.55 -122.13
# 2303900100         600.0      1997          0.00    98177 47.73 -122.37
#
#             sqft_living15  sqft_lot15
# id
# 9831200500           2660        7500
# 7237501190           5790       13539
# 1725059316           2200        9196
# 853200010            5070       20570
# 6762700020           3940        8800
# 1068000375           3130        6477
# 9208900037           4540       42730
# 3303850390           6110       26442
# 2426039123           2740       10761
# 4139900180           4760       35200
# 2303900100           3430       45302

# %% [markdown]
# ### Squarefoot Above

# %%
clean_column('sqft_above')

regplot('sqft_above')
# Out:
# Datatype: int64
# Total unique itms: 835
# Displaying first 10:
# [2170 1050 1680 3890 1715 1890  860 1370 1810 1980]
# Minimum value: 370.  Maximum value: 9410
# count   15762.00
# mean     1792.78
# std       828.40
# min       370.00
# 25%      1200.00
# 50%      1570.00
# 75%      2220.00
# max      9410.00
# Name: sqft_above, dtype: float64
# <AxesSubplot:xlabel='sqft_above', ylabel='price'>

# %%
hist('sqft_above')

# %% [markdown]
# ### Squarefoot Basement

# %%
clean_column('sqft_basement')
# Out:
# Datatype: object
# Total unique itms: 283
# Displaying first 10:
# ['400.0' '910.0' '0.0' '1530.0' '?' '730.0' '300.0' '970.0' '760.0'
#  '720.0']
# Minimum value: 0.0.  Maximum value: ?
# count     15762
# unique      283
# top         0.0
# freq       9362
# Name: sqft_basement, dtype: object
# 'sqft_basement'

# %% [markdown]
# It seems there are some errors with question marks.  Let's take a look.

# %%
df[df['sqft_basement'] == '?']
# Out:
#                  date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 1321400060 2014-06-27  257500.00         3       2.25         1715      6819
# 16000397   2014-12-05  189000.00         2       1.00         1200      9850
# 7203220400 2014-07-07  861990.00         5       2.75         3595      5639
# 1531000030 2015-03-23  720000.00         4       2.50         3450     39683
# 2525310310 2014-09-16  272500.00         3       1.75         1540     12600
# 1909600046 2014-07-03  445838.00         3       2.50         2250      5692
# 713500030  2014-07-28 1350000.00         5       3.50         4800     14984
# 5113400431 2014-05-08  615000.00         2       1.00         1540      6872
# 8832900550 2014-09-12  650000.00         3       2.50         2690     11575
# 1545804340 2015-04-09  240000.00         3       1.75         1760      6500
# 1775920350 2014-11-24  323000.00         3       1.00         1290     12231
# 5101405124 2014-09-12  435000.00         4       2.50         1700      6380
# 2346200030 2015-01-05  802541.00         5       2.75         2990      6768
# 5149300200 2014-09-02  316500.00         3       1.75         1600     14250
# 7749500370 2014-10-21  225000.00         4       2.25         1800      9350
# 9209900270 2015-02-05  515000.00         2       1.00         1060      4228
# 194000505  2014-09-04  651000.00         3       2.00         1940      6440
# 5589300370 2015-04-01  282000.00         4       1.00         1200     11111
# 2412600030 2014-06-23  235000.00         6       3.00         2180      7956
# 3623500135 2015-03-26  800000.00         4       2.25         2350     10664
# 65000260   2014-08-20  830000.00         3       2.50         3370      6550
# 1785500132 2014-11-18  293000.00         3       1.00         1020      7650
# 625059051  2014-09-03 2350000.00         4       2.25         4370     22863
# 2374200005           1780        8732
# 7802900500           2100       13500
# 1950900005           1170        7125
# 7922900460           2350        8937
# 8925100440           2760        6375
# 8078570460           1940        7432
# 3298700305            850        5200
# 2201500440           1240       11008
# 7701990380           3170       16397
# 7369600080           1780        5612
# 1934800022           1320        1676
# 3300701440           1060        4000
# 40000471             1700        9355
# 8864000425           1330        6099
# 9286100250           1670        2897
# 1545806720           1630        8800
# 3624039102            990        6800
# 4031000460           1188        9812
# 9348700450           3290        6978
# 7937900040           3620       41965
# 9266700845           1050        5100
# 7177300735           1420        5356
# 5100400315            920        5940
# 5141000571           1490        4650
# 4345000490           1770        7349
# 7011201106           1610        2666
# 2125049133           1970        5500
# 2472920740           2420        7663
# 7649900175           1670        5000
# 1868900775           1800        5000
# 3630000150           1380        1107
# 1337800665           2850        4800
# 1493300115           1220        5520
# 5416500040           1980        3800
# 7227800180           1940        8501
# 3308010040           1890       11368
# 9542200220           2490        9775
# 5631501161           1590        9900
# 5126210360           3250      111513
# 3886902615           2000        7680
# 6126601380           1760        5400
# 795002450            1280        7100
# 3204300610           2040        4560
# 284000025            2480       21503
# 224059021            2460       11781
# 9429400060           2100        3730
# 2626119062           1300        6849
# 291310270            1445        1370
# 5609000311           1360        5800
# 3845100160           2570        5000
# 2423069039           2270       54450
# 1732800194           1680         977
# 2623039019           1780       12310
# 7853350090           2990        6835
# 3630200780           3040        5474
# 1438000440           2590        4136
# 3879900750           1580        1279
# 3274800505           1130        2921
# 8850000517           1620        1548
# 3022900070           2304        5880
# 6130500120           1650        1965
# 9578140180           2478        7212
# 2568200120           3150        6593
# 2767601750           1510        2501
# 9274200322           1740        1280
# 291310180            1490        1435
# 7203230040           4080        8425
# 8564860130           3270        6037
# 3438500250           2910        5027
# 3278600680           1360        1730
# 2309710150           2380        5291
# 9521100301            820        1156
# 3226049565           2180        5009
# 2909310100           2380        5396

# %% [markdown]
# It might be best to go ahead and make a "True" and "False" boolean column for 'has_basement.'  We will also change all '?' values to zero (0) and conver the values into floats.

# %%
# df['sqft_basement'] = df['sqft_basement'].replace(['?'],0.0)

df['sqft_basement'] = df['sqft_living'] - df['sqft_above']

df.loc[df['sqft_basement'] == '?']
# Out:
# Empty DataFrame
# Columns: [date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []

# %%
df['sqft_basement'] = df['sqft_basement'].astype(float)

# %%
# run this line if need to rerun and delete 'has_basement'
# del df['has_basement']

has_basement = np.where(df['sqft_basement'] > 0, 1, 0)

df.insert (12, 'has_basement', has_basement)

df.head(5)
# Out:
#                  date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 6414100192 2014-12-09  538000.00         3       2.25         2570      7242
# 2487200875 2014-12-09  604000.00         4       3.00         1960      5000
# 1954400510 2015-02-18  510000.00         3       2.00         1680      8080
# 7237550310 2014-05-12 1230000.00         4       4.50         5420    101930
# 1321400060 2014-06-27  257500.00         3       2.25         1715      6819
#
#             floors  waterfront  view  condition  ...  sqft_above  \
# id                                               ...
# 6414100192    2.00        0.00  0.00          3  ...        2170
# 2487200875    1.00        0.00  0.00          5  ...        1050
# 1954400510    1.00        0.00  0.00          3  ...        1680
# 7237550310    1.00        0.00  0.00          3  ...        3890
# 1321400060    2.00        0.00  0.00          3  ...        1715
#
#             has_basement  sqft_basement  yr_built  yr_renovated  zipcode  \
# id
# 6414100192             1         400.00      1951       1991.00    98125
# 2487200875             1         910.00      1965          0.00    98136
# 1954400510             0           0.00      1987          0.00    98074
# 7237550310             1        1530.00      2001          0.00    98053
# 1321400060             0           0.00      1995          0.00    98003
#
#              lat    long  sqft_living15  sqft_lot15
# id
# 6414100192 47.72 -122.32           1690        7639
# 2487200875 47.52 -122.39           1360        5000
# 1954400510 47.62 -122.05           1800        7503
# 7237550310 47.66 -122.00           4760      101930
# 1321400060 47.31 -122.33           2238        6819
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Year Built

# %%
clean_column('yr_built')

regplot('yr_built')
# Out:
# Datatype: int64
# Total unique itms: 116
# Displaying first 10:
# [1951 1965 1987 2001 1995 1960 2003 1942 1977 1900]
# Minimum value: 1900.  Maximum value: 2015
# count   15762.00
# mean     1971.11
# std        29.34
# min      1900.00
# 25%      1952.00
# 50%      1975.00
# 75%      1997.00
# max      2015.00
# Name: yr_built, dtype: float64
# <AxesSubplot:xlabel='yr_built', ylabel='price'>

# %%
hist('yr_built')

# %% [markdown]
# We will convert this to age to more easily interpret this feature in our model.

# %%
df['age'] = abs(df['yr_built'] - 2015)

df.head()
# Out:
#                  date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 6414100192 2014-12-09  538000.00         3       2.25         2570      7242
# 2487200875 2014-12-09  604000.00         4       3.00         1960      5000
# 1954400510 2015-02-18  510000.00         3       2.00         1680      8080
# 7237550310 2014-05-12 1230000.00         4       4.50         5420    101930
# 1321400060 2014-06-27  257500.00         3       2.25         1715      6819
#
#             floors  waterfront  view  condition  ...  has_basement  \
# id                                               ...
# 6414100192    2.00        0.00  0.00          3  ...             1
# 2487200875    1.00        0.00  0.00          5  ...             1
# 1954400510    1.00        0.00  0.00          3  ...             0
# 7237550310    1.00        0.00  0.00          3  ...             1
# 1321400060    2.00        0.00  0.00          3  ...             0
#
#             sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# id
# 6414100192         400.00      1951       1991.00    98125 47.72 -122.32
# 2487200875         910.00      1965          0.00    98136 47.52 -122.39
# 1954400510           0.00      1987          0.00    98074 47.62 -122.05
# 7237550310        1530.00      2001          0.00    98053 47.66 -122.00
# 1321400060           0.00      1995          0.00    98003 47.31 -122.33
#
#             sqft_living15  sqft_lot15  age
# id
# 6414100192           1690        7639   64
# 2487200875           1360        5000   50
# 1954400510           1800        7503   28
# 7237550310           4760      101930   14
# 1321400060           2238        6819   20
#
# [5 rows x 22 columns]

# %%
clean_column('age')

hist('age')
# Out:
# Datatype: int64
# Total unique itms: 116
# Displaying first 10:
# [ 64  50  28  14  20  55  12  73  38 115]
# Minimum value: 0.  Maximum value: 115
# count   15762.00
# mean       43.89
# std        29.34
# min         0.00
# 25%        18.00
# 50%        40.00
# 75%        63.00
# max       115.00
# Name: age, dtype: float64

# %%
del df['yr_built']

# %% [markdown]
# ### Year Renovated

# %%
clean_column('yr_renovated')

regplot('yr_renovated')
# Out:
# Datatype: float64
# Total unique itms: 70
# Displaying first 10:
# [1991.    0. 2002. 2010. 1992. 2013. 1994. 1978. 2005. 2003.]
# Minimum value: 0.0.  Maximum value: 2015.0
# count   15762.00
# mean       82.44
# std       397.21
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max      2015.00
# Name: yr_renovated, dtype: float64
# <AxesSubplot:xlabel='yr_renovated', ylabel='price'>

# %% [markdown]
# Convert to binary.

# %%
renovated = np.where(df['yr_renovated'] > 0, 1, 0)

df['renovated'] = renovated

del df['yr_renovated']

df.head(5)
# Out:
#                  date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 6414100192 2014-12-09  538000.00         3       2.25         2570      7242
# 2487200875 2014-12-09  604000.00         4       3.00         1960      5000
# 1954400510 2015-02-18  510000.00         3       2.00         1680      8080
# 7237550310 2014-05-12 1230000.00         4       4.50         5420    101930
# 1321400060 2014-06-27  257500.00         3       2.25         1715      6819
#
#             floors  waterfront  view  condition  ...  sqft_above  \
# id                                               ...
# 6414100192    2.00        0.00  0.00          3  ...        2170
# 2487200875    1.00        0.00  0.00          5  ...        1050
# 1954400510    1.00        0.00  0.00          3  ...        1680
# 7237550310    1.00        0.00  0.00          3  ...        3890
# 1321400060    2.00        0.00  0.00          3  ...        1715
#
#             has_basement  sqft_basement  zipcode   lat    long  sqft_living15  \
# id
# 6414100192             1         400.00    98125 47.72 -122.32           1690
# 2487200875             1         910.00    98136 47.52 -122.39           1360
# 1954400510             0           0.00    98074 47.62 -122.05           1800
# 7237550310             1        1530.00    98053 47.66 -122.00           4760
# 1321400060             0           0.00    98003 47.31 -122.33           2238
#
#             sqft_lot15  age  renovated
# id
# 6414100192        7639   64          1
# 2487200875        5000   50          0
# 1954400510        7503   28          0
# 7237550310      101930   14          0
# 1321400060        6819   20          0
#
# [5 rows x 21 columns]

# %%
df.head()
# Out:
#                  date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 6414100192 2014-12-09  538000.00         3       2.25         2570      7242
# 2487200875 2014-12-09  604000.00         4       3.00         1960      5000
# 1954400510 2015-02-18  510000.00         3       2.00         1680      8080
# 7237550310 2014-05-12 1230000.00         4       4.50         5420    101930
# 1321400060 2014-06-27  257500.00         3       2.25         1715      6819
#
#             floors  waterfront  view  condition  ...  sqft_above  \
# id                                               ...
# 6414100192    2.00        0.00  0.00          3  ...        2170
# 2487200875    1.00        0.00  0.00          5  ...        1050
# 1954400510    1.00        0.00  0.00          3  ...        1680
# 7237550310    1.00        0.00  0.00          3  ...        3890
# 1321400060    2.00        0.00  0.00          3  ...        1715
#
#             has_basement  sqft_basement  zipcode   lat    long  sqft_living15  \
# id
# 6414100192             1         400.00    98125 47.72 -122.32           1690
# 2487200875             1         910.00    98136 47.52 -122.39           1360
# 1954400510             0           0.00    98074 47.62 -122.05           1800
# 7237550310             1        1530.00    98053 47.66 -122.00           4760
# 1321400060             0           0.00    98003 47.31 -122.33           2238
#
#             sqft_lot15  age  renovated
# id
# 6414100192        7639   64          1
# 2487200875        5000   50          0
# 1954400510        7503   28          0
# 7237550310      101930   14          0
# 1321400060        6819   20          0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Zipcode

# %%
clean_column('zipcode')
# Out:
# Datatype: int64
# Total unique itms: 70
# Displaying first 10:
# [98125 98136 98074 98053 98003 98146 98038 98115 98107 98126]
# Minimum value: 98001.  Maximum value: 98199
# count   15762.00
# mean    98077.56
# std        53.41
# min     98001.00
# 25%     98033.00
# 50%     98065.00
# 75%     98117.00
# max     98199.00
# Name: zipcode, dtype: float64
# 'zipcode'

# %% [markdown]
# Zipcode should be integer for now, since there will be no decimals.  It might be worth considering conversion to string as well further in the project.

# %%
df['zipcode'] = df['zipcode'].astype(int)

# %%
clean_column('zipcode')

regplot('zipcode')
# Out:
# Datatype: int32
# Total unique itms: 70
# Displaying first 10:
# [98125 98136 98074 98053 98003 98146 98038 98115 98107 98126]
# Minimum value: 98001.  Maximum value: 98199
# count   15762.00
# mean    98077.56
# std        53.41
# min     98001.00
# 25%     98033.00
# 50%     98065.00
# 75%     98117.00
# max     98199.00
# Name: zipcode, dtype: float64
# <AxesSubplot:xlabel='zipcode', ylabel='price'>

# %%
hist('zipcode')

# %% [markdown]
# ### 'sqft_living15'
#
# The square footage of interior housing living space for the nearest 15 neighbors

# %%
clean_column('sqft_living15')

regplot('sqft_living15')
# Out:
# Datatype: int64
# Total unique itms: 694
# Displaying first 10:
# [1690 1360 1800 4760 2238 1780 2390 1330 1370 2140]
# Minimum value: 399.  Maximum value: 6210
# count   15762.00
# mean     1990.22
# std       684.14
# min       399.00
# 25%      1490.00
# 50%      1846.00
# 75%      2370.00
# max      6210.00
# Name: sqft_living15, dtype: float64
# <AxesSubplot:xlabel='sqft_living15', ylabel='price'>

# %%
hist('sqft_living15')

# %% [markdown]
# ### 'sqft_lot15'
#
# The square footage of the land lots of the nearest 15 neighbors

# %%
clean_column('sqft_lot15')

regplot('sqft_lot15')
# Out:
# Datatype: int64
# Total unique itms: 7126
# Displaying first 10:
# [  7639   5000   7503 101930   6819   8113   7570   6000  10208   4850]
# Minimum value: 659.  Maximum value: 871200
# count    15762.00
# mean     12900.42
# std      27977.23
# min        659.00
# 25%       5100.00
# 50%       7620.00
# 75%      10107.50
# max     871200.00
# Name: sqft_lot15, dtype: float64
# <AxesSubplot:xlabel='sqft_lot15', ylabel='price'>

# %%
hist('sqft_lot15')

# %% [markdown]
# ## Remove Outliers

# %%
fig, ax = plt.subplots(figsize=(12, 4))
ax = sns.boxplot(df['price'])
# Out:
# C:\Users\Johnny\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Target Variable (price)

# %%
column = 'price'

describe = df.describe()[column]

q1 = describe['25%']
q3 = describe['75%']

iqr = q3 - q1

outlier_index = (df[column] > (q3 + 1.5 * iqr)) | (df[column] < (q1 - 1.5 * iqr))

df[outlier_index].shape
# Out:
# (831, 21)

# %%
regplot('sqft_living', df=df)
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
regplot('sqft_living', df=df[~outlier_index])
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
df = df[~outlier_index]

# %% [markdown]
# ### Squarefoot Living

# %%
column = 'sqft_living'

describe = df.describe()[column]

q1 = describe['25%']
q3 = describe['75%']

iqr = q3 - q1

outlier_index = (df[column] > (q3 + 1.5 * iqr)) | (df[column] < (q1 - 1.5 * iqr))

df[outlier_index].shape
# Out:
# (216, 21)

# %%
regplot('sqft_living', df=df)
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
regplot('sqft_living', df=df[~outlier_index])
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
df = df[~outlier_index]

# %% [markdown]
# ### Squarefoot Lot

# %%
column = 'sqft_lot'

describe = df.describe()[column]

q1 = describe['25%']
q3 = describe['75%']

iqr = q3 - q1

outlier_index = (df[column] > (q3 + 1.5 * iqr)) | (df[column] < (q1 - 1.5 * iqr))

df[outlier_index].shape
# Out:
# (1587, 21)

# %%
regplot('sqft_lot', df=df)
# Out:
# <AxesSubplot:xlabel='sqft_lot', ylabel='price'>

# %%
regplot('sqft_lot', df=df[~outlier_index])
# Out:
# <AxesSubplot:xlabel='sqft_lot', ylabel='price'>

# %%
df = df[~outlier_index]

# %% [markdown]
# # EXPLORE

# %% [markdown]
# Now that we're comfortable that we have quality data, it's time to determine which columns we'll want to analyze for our primary analysis.
#
# First we'll review which columns we have to work with:

# %%
# df.info()

# %% [markdown]
# Based on prior anaysis and scrubbing, we'll categorize our columns into three sections:

# %% [markdown]
# Continuous variables:
# - price
# - sqft_living
# - sqft_lot
# - sqft_above
# - sqft_basement
# - yr_built
# - sqft_living15
# - sqft_lot15
#
# Categorical variables - while some of these may appear continuous, their values represent integers and fractions that are more categorical even if they are for a specific count.
# - bedrooms
# - bathrooms
# - floors
# - condition
# - grade
# - waterfront
# - renovated
# - zipcode
# - has_basement
#
# Remove from model:
# - date - date of sale could be interesting to analyze if we had a longer time horizon.  Home prices could sell for more less based on season, and this could be interesting for further analysis
# - lat - will not have a linear relationship
# - long - will not have a linear relationship
# - view - while we have a range of values, the column description reads "Has been viewed" which should be binary.  Seems like there could be an error, further review could make this column eligible for future analysis

# %%
df.drop(['date', 'lat', 'long', 'view'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id
# 6414100192 538000.00         3       2.25         2570      7242    2.00
# 2487200875 604000.00         4       3.00         1960      5000    1.00
# 1954400510 510000.00         3       2.00         1680      8080    1.00
# 1321400060 257500.00         3       2.25         1715      6819    2.00
# 2414600126 229500.00         3       1.00         1780      7470    1.00
#
#             waterfront  condition  grade  sqft_above  has_basement  \
# id
# 6414100192        0.00          3      7        2170             1
# 2487200875        0.00          5      7        1050             1
# 1954400510        0.00          3      8        1680             0
# 1321400060        0.00          3      7        1715             0
# 2414600126        0.00          3      7        1050             1
#
#             sqft_basement  zipcode  sqft_living15  sqft_lot15  age  renovated
# id
# 6414100192         400.00    98125           1690        7639   64          1
# 2487200875         910.00    98136           1360        5000   50          0
# 1954400510           0.00    98074           1800        7503   28          0
# 1321400060           0.00    98003           2238        6819   20          0
# 2414600126         730.00    98146           1780        8113   55          0

# %% [markdown]
# ## Multicollinearity

# %% [markdown]
# We will create a heat map to identify multicollinearity.

# %%
def heatmap(df_name, figsize=(15,10), cmap='Reds'):
    corr = df_name.drop('price',axis=1).corr()
    mask = np.zeros_like(corr)
    mask[np.triu_indices_from(mask)] = True
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(corr, annot=True, cmap=cmap, mask=mask)
    return fig, ax

heatmap(df)
# Out:
# (<Figure size 1080x720 with 2 Axes>, <AxesSubplot:>)

# %% [markdown]
# We will drop the following:
#
# sqft_above + sqft_basement - these are duplicative of sqft_living.
#
# sqft_lot15 and sqft_living15 - these could be more interesting for broader analysis of areas.  Since there is high multicolinearity, we can save these for when we look at zip, lat, and long.

# %%
del df['sqft_above']
del df['sqft_basement']
del df['sqft_lot15']
del df['sqft_living15']

# %%
heatmap(df)
# Out:
# (<Figure size 1080x720 with 2 Axes>, <AxesSubplot:>)

# %% [markdown]
# If we're defining multicollinear variables as having a correlation of 0.75 and higher, then our only example is sqft_above and grade at 0.76.  We could surmise that that there is a relationship between larger homes and overall grade given between King County grading system.  However, it seems inappropriate to remove grade, since it seems intuitive that there might be some highly graded smaller homes.
#
# We are ready to move to the next step.

# %% [markdown]
# # One Hot Variables

# %%
# https://nbviewer.jupyter.org/github/examsherpa/King-County-Housing-Price-Prediction/blob/main/housing_modeling.ipynb

# dummies = df[]

# df_preprocessed = df.drop(categoricals, axis=1)

# df_preprocessed = pd.concat([df_preprocessed, dummies], axis=1)

# df_preprocessed.head()

# %%
# dummies

# %% [markdown]
# # MODEL

# %% [markdown]
# ## Data Modeling
# Describe and justify the process for analyzing or modeling the data.
#
# ***
# Questions to consider:
# * How did you analyze or model the data?
# * How did you iterate on your initial approach to make it better?
# * Why are these choices appropriate given the data and the business problem?
# ***

# %%
df.head()
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id
# 6414100192 538000.00         3       2.25         2570      7242    2.00
# 2487200875 604000.00         4       3.00         1960      5000    1.00
# 1954400510 510000.00         3       2.00         1680      8080    1.00
# 1321400060 257500.00         3       2.25         1715      6819    2.00
# 2008000270 291850.00         3       1.50         1060      9711    1.00
#
#             waterfront  condition  grade  has_basement  zipcode  age  \
# id
# 6414100192        0.00          3      7             1    98125   64
# 2487200875        0.00          5      7             1    98136   50
# 1954400510        0.00          3      8             0    98074   28
# 1321400060        0.00          3      7             0    98003   20
# 2008000270        0.00          3      7             0    98198   52
#
#             renovated
# id
# 6414100192          1
# 2487200875          0
# 1954400510          0
# 1321400060          0
# 2008000270          0

# %% [markdown]
# ## VIF Multicollinearity Check

# %%
# # !pip install -U fsds
# from scipy import stats
# from fsds.imports import *

# import statsmodels.api as sm
# import statsmodels.stats.api as sms
# import statsmodels.formula.api as smf
# import scipy.stats as stats

# import scipy.stats as stats
# # import statsmodels.api as sms

# %%
# def make_model(df_name):

#     features = ' + '.join(df_name.drop('price',axis=1).columns)

#     f  = "price~"+features

#     model = smf.ols(f, df_name).fit()
#     display(model.summary())
#     return model
    
# # model(df)

# %%
# from statsmodels.stats.outliers_influence import variance_inflation_factor

# # x_cols = ['bedrooms', 'bathrooms', 'sqft_lot', 'floors', 'waterfront',
# #        'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built']

# x_cols = ['bedrooms', 'bathrooms', 'floors',
#        'waterfront', 'condition', 'grade', 'has_basement',
#        'renovated']

# for col in x_cols:
#     df[col] = (df[col] - df[col].mean())/df[col].std()

# X = df[x_cols]
# vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
# list(zip(x_cols, vif))

# %%
# x_cols = ['price', 'sqft_lot', 'waterfront',
#        'condition', 'sqft_above', 'sqft_basement']

# make_model(df[x_cols])

# %%
# model(df)

# %%
# def make_model(df_name):

#     features = ' + '.join(df_name.drop('price',axis=1).columns)

#     f  = "price~"+features

#     model = smf.ols(f, df_name).fit()
#     display(model.summary())
#     return model
    
# model1 = make_model(df)

# %%
# model1.pvalues

# pvals = model1.pvalues

# pvals[pvals > 0.05]
# # pvals[pvals > 0.05].index

# %%
# model1.pvalues

# pvals = model1.pvalues

# pvals[pvals > 0.05].index

# %% [markdown]
# ## Model integer check

# %%
df
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id
# 6414100192 538000.00         3       2.25         2570      7242    2.00
# 2487200875 604000.00         4       3.00         1960      5000    1.00
# 1954400510 510000.00         3       2.00         1680      8080    1.00
# 1321400060 257500.00         3       2.25         1715      6819    2.00
# 2008000270 291850.00         3       1.50         1060      9711    1.00
# ...              ...       ...        ...          ...       ...     ...
# 2997800021 475000.00         3       2.50         1310      1294    2.00
# 263000018  360000.00         3       2.50         1530      1131    3.00
# 6600060120 400000.00         4       2.50         2310      5813    2.00
# 1523300141 402101.00         2       0.75         1020      1350    2.00
# 1523300157 325000.00         2       0.75         1020      1076    2.00
#
#             waterfront  condition  grade  has_basement  zipcode  age  \
# id
# 6414100192        0.00          3      7             1    98125   64
# 2487200875        0.00          5      7             1    98136   50
# 1954400510        0.00          3      8             0    98074   28
# 1321400060        0.00          3      7             0    98003   20
# 2008000270        0.00          3      7             0    98198   52
# ...                ...        ...    ...           ...      ...  ...
# 2997800021        0.00          3      8             1    98116    7
# 263000018         0.00          3      8             0    98103    6
# 6600060120        0.00          3      8             0    98146    1
# 1523300141        0.00          3      7             0    98144    6
# 1523300157        0.00          3      7             0    98144    7
#
#             renovated
# id
# 6414100192          1
# 2487200875          0
# 1954400510          0
# 1321400060          0
# 2008000270          0
# ...               ...
# 2997800021          0
# 263000018           0
# 6600060120          0
# 1523300141          0
# 1523300157          0
#
# [14959 rows x 13 columns]

# %% [markdown]
# ## Categorical Variables

# %%
#if majority of zipcodes are not significant, drop whole column and vice versa.

categoricals = ['bedrooms', 
                'bathrooms', 
                'floors', 
                'waterfront', 
                'condition', 
                'grade', 
                'has_basement',
                'zipcode',
                'renovated']

categoricals
# Out:
# ['bedrooms',
#  'bathrooms',
#  'floors',
#  'waterfront',
#  'condition',
#  'grade',
#  'has_basement',
#  'zipcode',
#  'renovated']

# %%
# !pip install -U fsds
from scipy import stats
from fsds.imports import *

import statsmodels.api as sm
import statsmodels.stats.api as sms
import statsmodels.formula.api as smf
import scipy.stats as stats

import scipy.stats as stats
import statsmodels.api as sms
# Out:
# Requirement already up-to-date: fsds in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (0.3.2)
# Requirement already satisfied, skipping upgrade: cufflinks>=0.17.0 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from fsds) (0.17.3)
# Requirement already satisfied, skipping upgrade: pandas>=1.1.0 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from fsds) (1.1.3)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.23.1 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from fsds) (0.23.2)
# Requirement already satisfied, skipping upgrade: IPython in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from fsds) (7.18.1)
# Requirement already satisfied, skipping upgrade: seaborn>=0.11.0 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from fsds) (0.11.0)
# Requirement already satisfied, skipping upgrade: plotly>=4.0.0 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from fsds) (4.11.0)
# Requirement already satisfied, skipping upgrade: missingno in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from fsds) (0.4.2)
# Requirement already satisfied, skipping upgrade: ipywidgets in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from fsds) (7.5.1)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.2.2 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from fsds) (3.3.1)
# Requirement already satisfied, skipping upgrade: scipy in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from fsds) (1.5.0)
# Requirement already satisfied, skipping upgrade: tzlocal in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from fsds) (2.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.18.0 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from fsds) (1.18.5)
# Requirement already satisfied, skipping upgrade: pyperclip in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from fsds) (1.8.2)
# Requirement already satisfied, skipping upgrade: setuptools>=34.4.1 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from cufflinks>=0.17.0->fsds) (50.3.0.post20201103)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from cufflinks>=0.17.0->fsds) (1.15.0)
# Requirement already satisfied, skipping upgrade: colorlover>=0.2.1 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from cufflinks>=0.17.0->fsds) (0.3.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from pandas>=1.1.0->fsds) (2020.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from pandas>=1.1.0->fsds) (2.8.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from scikit-learn>=0.23.1->fsds) (0.17.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from scikit-learn>=0.23.1->fsds) (2.1.0)
# Requirement already satisfied, skipping upgrade: pickleshare in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from IPython->fsds) (0.7.5)
# Requirement already satisfied, skipping upgrade: pygments in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from IPython->fsds) (2.7.1)
# Requirement already satisfied, skipping upgrade: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from IPython->fsds) (3.0.8)
# Requirement already satisfied, skipping upgrade: traitlets>=4.2 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from IPython->fsds) (5.0.5)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from IPython->fsds) (0.17.2)
# Requirement already satisfied, skipping upgrade: backcall in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from IPython->fsds) (0.2.0)
# Requirement already satisfied, skipping upgrade: decorator in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from IPython->fsds) (4.4.2)
# Requirement already satisfied, skipping upgrade: colorama; sys_platform == "win32" in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from IPython->fsds) (0.4.3)
# Requirement already satisfied, skipping upgrade: retrying>=1.3.3 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from plotly>=4.0.0->fsds) (1.3.3)
# Requirement already satisfied, skipping upgrade: ipykernel>=4.5.1 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from ipywidgets->fsds) (5.3.4)
# Requirement already satisfied, skipping upgrade: widgetsnbextension~=3.5.0 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from ipywidgets->fsds) (3.5.1)
# Requirement already satisfied, skipping upgrade: nbformat>=4.2.0 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from ipywidgets->fsds) (5.0.8)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from matplotlib>=3.2.2->fsds) (2.4.7)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from matplotlib>=3.2.2->fsds) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from matplotlib>=3.2.2->fsds) (1.2.0)
# Requirement already satisfied, skipping upgrade: certifi>=2020.06.20 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from matplotlib>=3.2.2->fsds) (2020.12.5)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from matplotlib>=3.2.2->fsds) (8.0.0)
# Requirement already satisfied, skipping upgrade: wcwidth in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->fsds) (0.2.5)
# Requirement already satisfied, skipping upgrade: ipython-genutils in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from traitlets>=4.2->IPython->fsds) (0.2.0)
# Requirement already satisfied, skipping upgrade: parso<0.8.0,>=0.7.0 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from jedi>=0.10->IPython->fsds) (0.7.0)
# Requirement already satisfied, skipping upgrade: jupyter-client in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->fsds) (6.1.7)
# Requirement already satisfied, skipping upgrade: tornado>=4.2 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->fsds) (6.0.4)
# Requirement already satisfied, skipping upgrade: notebook>=4.4.1 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets->fsds) (6.1.4)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from nbformat>=4.2.0->ipywidgets->fsds) (3.2.0)
# Requirement already satisfied, skipping upgrade: jupyter-core in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from nbformat>=4.2.0->ipywidgets->fsds) (4.6.3)
# Requirement already satisfied, skipping upgrade: pyzmq>=13 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->fsds) (19.0.2)
# Requirement already satisfied, skipping upgrade: jinja2 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (2.11.2)
# Requirement already satisfied, skipping upgrade: terminado>=0.8.3 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (0.9.1)
# Requirement already satisfied, skipping upgrade: prometheus-client in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (0.8.0)
# Requirement already satisfied, skipping upgrade: nbconvert in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (6.0.7)
# Requirement already satisfied, skipping upgrade: Send2Trash in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (1.5.0)
# Requirement already satisfied, skipping upgrade: argon2-cffi in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (20.1.0)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->fsds) (0.17.3)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->fsds) (20.2.0)
# Requirement already satisfied, skipping upgrade: pywin32>=1.0; sys_platform == "win32" in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets->fsds) (227)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (1.1.1)
# Requirement already satisfied, skipping upgrade: pywinpty>=0.5; os_name == "nt" in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (0.5.7)
# Requirement already satisfied, skipping upgrade: mistune<2,>=0.8.1 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (0.8.4)
# Requirement already satisfied, skipping upgrade: nbclient<0.6.0,>=0.5.0 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (0.5.1)
# Requirement already satisfied, skipping upgrade: entrypoints>=0.2.2 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (0.3)
# Requirement already satisfied, skipping upgrade: testpath in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (0.4.4)
# Requirement already satisfied, skipping upgrade: jupyterlab-pygments in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (0.1.2)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (1.4.2)
# Requirement already satisfied, skipping upgrade: bleach in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (3.2.1)
# Requirement already satisfied, skipping upgrade: defusedxml in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (0.6.0)
# Requirement already satisfied, skipping upgrade: cffi>=1.0.0 in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (1.14.3)
# Requirement already satisfied, skipping upgrade: nest-asyncio in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (1.4.1)
# Requirement already satisfied, skipping upgrade: async-generator in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (1.10)
# Requirement already satisfied, skipping upgrade: packaging in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (20.4)
# Requirement already satisfied, skipping upgrade: webencodings in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (0.5.1)
# Requirement already satisfied, skipping upgrade: pycparser in c:\users\johnny\anaconda3\envs\learn-env\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fsds) (2.20)

# %%
categoricals = ['bedrooms', 
                'bathrooms', 
                'floors', 
                'waterfront', 
                'condition', 
                'grade', 
                'has_basement',
                'zipcode',
                'renovated']

# %%
def check_model(model):

    resids = model.resid

    fig,ax = plt.subplots(ncols=2,figsize=(12,5))
    sms.qqplot(resids, stats.distributions.norm, fit=True, line='45',ax=ax[0])
    xs = np.linspace(0,1,len(resids))

    y_hat = model.predict(df)
    y = df['price']
    resid = y - y_hat
    plot = plt.scatter(x=y_hat, y=resid)
    plt.axhline(0)

    ax[1].scatter(x=y_hat,y=resid)
    
    return fig,ax

# check_model(model1)

# %%
def make_model(df_name, categoricals=categoricals):

    features = ' + '.join(df.drop('price',axis=1).columns)
    for variable in categoricals:
        features = features.replace(variable, ("C(" + variable + ")"))

    f  = "price~"+features

    model = smf.ols(f, df_name).fit()
    display(model.summary())

    fig,ax = check_model(model)
    plt.show()
    
    return model

model1 = make_model(df)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.824
# Method:                 Least Squares   F-statistic:                     567.1
# Date:                Tue, 20 Apr 2021   Prob (F-statistic):               0.00
# Time:                        11:49:15   Log-Likelihood:            -1.9129e+05
# No. Observations:               14959   AIC:                         3.828e+05
# Df Residuals:                   14834   BIC:                         3.838e+05
# Df Model:                         124
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept            -4.409e+04   1.04e+05     -0.424      0.671   -2.48e+05     1.6e+05
# C(bedrooms)[T.2]      1.694e+04   8009.594      2.115      0.034    1242.606    3.26e+04
# C(bedrooms)[T.3]      2.057e+04   8034.788      2.560      0.010    4815.931    3.63e+04
# C(bedrooms)[T.4]      1.712e+04   8219.594      2.083      0.037    1009.496    3.32e+04
# C(bedrooms)[T.5]      -790.3545   8715.036     -0.091      0.928   -1.79e+04    1.63e+04
# C(bedrooms)[T.6]     -9254.1033   1.09e+04     -0.850      0.395   -3.06e+04    1.21e+04
# C(bedrooms)[T.7]     -6.834e+04   2.38e+04     -2.867      0.004   -1.15e+05   -2.16e+04
# C(bedrooms)[T.8]     -6.422e+04   3.73e+04     -1.721      0.085   -1.37e+05    8931.899
# C(bedrooms)[T.9]     -3.293e+04   5.16e+04     -0.638      0.523   -1.34e+05    6.82e+04
# C(bedrooms)[T.10]      -7.7e+04   6.24e+04     -1.235      0.217   -1.99e+05    4.52e+04
# C(bathrooms)[T.0.75]  7.542e+04   5.19e+04      1.452      0.147   -2.64e+04    1.77e+05
# C(bathrooms)[T.1.0]   6.068e+04   5.04e+04      1.204      0.229   -3.81e+04    1.59e+05
# C(bathrooms)[T.1.25] -1392.7856   6.38e+04     -0.022      0.983   -1.26e+05    1.24e+05
# C(bathrooms)[T.1.5]   6.176e+04   5.05e+04      1.223      0.221   -3.72e+04    1.61e+05
# C(bathrooms)[T.1.75]  7.077e+04   5.05e+04      1.402      0.161   -2.82e+04     1.7e+05
# C(bathrooms)[T.2.0]   6.653e+04   5.05e+04      1.317      0.188   -3.25e+04    1.66e+05
# C(bathrooms)[T.2.25]  7.939e+04   5.05e+04      1.571      0.116   -1.97e+04    1.78e+05
# C(bathrooms)[T.2.5]   8.313e+04   5.05e+04      1.645      0.100   -1.59e+04    1.82e+05
# C(bathrooms)[T.2.75]  9.732e+04   5.06e+04      1.923      0.054   -1869.926    1.97e+05
# C(zipcode)[T.98146]   1.057e+05   8144.860     12.978      0.000    8.97e+04    1.22e+05
# C(zipcode)[T.98148]   5.191e+04   1.45e+04      3.574      0.000    2.34e+04    8.04e+04
# C(zipcode)[T.98155]   1.389e+05   7397.812     18.770      0.000    1.24e+05    1.53e+05
# C(zipcode)[T.98166]    1.14e+05   8531.887     13.364      0.000    9.73e+04    1.31e+05
# C(zipcode)[T.98168]   4.273e+04   8368.988      5.105      0.000    2.63e+04    5.91e+04
# C(zipcode)[T.98177]   2.382e+05   8712.003     27.346      0.000    2.21e+05    2.55e+05
# C(zipcode)[T.98178]   6.398e+04   8457.763      7.565      0.000    4.74e+04    8.06e+04
# C(zipcode)[T.98188]   3.145e+04   1.04e+04      3.024      0.002    1.11e+04    5.18e+04
# C(zipcode)[T.98198]   3.653e+04   8201.003      4.455      0.000    2.05e+04    5.26e+04
# C(zipcode)[T.98199]   3.524e+05   8514.390     41.387      0.000    3.36e+05    3.69e+05
# C(renovated)[T.1]     3.547e+04   4086.007      8.680      0.000    2.75e+04    4.35e+04
# sqft_living            112.2350      1.920     58.449      0.000     108.471     115.999
# sqft_lot                 0.3237      0.019     16.727      0.000       0.286       0.362
# age                    435.0647     47.486      9.162      0.000     341.986     528.143
# ==============================================================================
# Omnibus:                     1566.506   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5501.808
# Skew:                           0.511   Prob(JB):                         0.00
# Kurtosis:                       5.790   Cond. No.                     1.72e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.72e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## Refining based on P-values

# %%
model1.pvalues

pvals = model1.pvalues

pvals[pvals > 0.05]
# pvals[pvals > 0.05].index
# Out:
# Intercept              0.67
# C(bedrooms)[T.5]       0.93
# C(bedrooms)[T.6]       0.40
# C(bedrooms)[T.8]       0.09
# C(bedrooms)[T.9]       0.52
# C(bedrooms)[T.10]      0.22
# C(bathrooms)[T.0.75]   0.15
# C(bathrooms)[T.1.0]    0.23
# C(bathrooms)[T.1.25]   0.98
# C(bathrooms)[T.1.5]    0.22
# C(bathrooms)[T.1.75]   0.16
# C(bathrooms)[T.2.0]    0.19
# C(bathrooms)[T.2.25]   0.12
# C(bathrooms)[T.2.5]    0.10
# C(bathrooms)[T.2.75]   0.05
# C(bathrooms)[T.3.0]    0.09
# C(bathrooms)[T.4.0]    0.05
# C(bathrooms)[T.4.25]   0.07
# C(bathrooms)[T.4.5]    0.18
# C(bathrooms)[T.4.75]   0.90
# C(bathrooms)[T.5.0]    0.99
# C(bathrooms)[T.5.25]   0.15
# C(bathrooms)[T.5.75]   0.91
# C(bathrooms)[T.7.5]    0.18
# C(floors)[T.1.5]       0.12
# C(floors)[T.3.5]       0.06
# C(condition)[T.2]      0.14
# C(grade)[T.4]          0.27
# C(grade)[T.5]          0.16
# C(grade)[T.6]          0.16
# C(grade)[T.7]          0.29
# C(grade)[T.8]          0.63
# C(grade)[T.9]          0.67
# C(grade)[T.10]         0.34
# C(grade)[T.11]         0.05
# C(grade)[T.12]         0.19
# C(zipcode)[T.98002]    0.55
# C(zipcode)[T.98003]    0.99
# C(zipcode)[T.98022]    0.21
# C(zipcode)[T.98030]    0.49
# C(zipcode)[T.98031]    0.07
# C(zipcode)[T.98032]    0.59
# C(zipcode)[T.98042]    0.11
# C(zipcode)[T.98092]    0.18
# dtype: float64

# %% [markdown]
# It seems that certain bedroom numbers don't have a significant effect.  Bathrooms have very little effect.  1.5 and 3.5 floors might not have an effect, likely due to low representaion in dataset.  Some conditions seems important, grade seems negligible, and a 12 of the 69 zip codes can be removed.
#
# We will remove the following columns:
#
# bedrooms
#
# bathrooms
#
# grade

# %%
df = df.drop(['bedrooms', 'bathrooms', 'grade'], axis=1)

# %%
categoricals = [
#                 'bedrooms', 
#                 'bathrooms', 
                'floors', 
                'waterfront', 
                'condition', 
#                 'grade', 
                'has_basement',
                'zipcode',
                'renovated'
                ]

# %%
df.head()
# Out:
#                price  sqft_living  sqft_lot  floors  waterfront  condition  \
# id
# 6414100192 538000.00         2570      7242    2.00        0.00          3
# 2487200875 604000.00         1960      5000    1.00        0.00          5
# 1954400510 510000.00         1680      8080    1.00        0.00          3
# 1321400060 257500.00         1715      6819    2.00        0.00          3
# 2008000270 291850.00         1060      9711    1.00        0.00          3
#
#             has_basement  zipcode  age  renovated
# id
# 6414100192             1    98125   64          1
# 2487200875             1    98136   50          0
# 1954400510             0    98074   28          0
# 1321400060             0    98003   20          0
# 2008000270             0    98198   52          0

# %%
model1 = make_model(df, categoricals)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.792
# Model:                            OLS   Adj. R-squared:                  0.790
# Method:                 Least Squares   F-statistic:                     672.6
# Date:                Tue, 20 Apr 2021   Prob (F-statistic):               0.00
# Time:                        11:49:17   Log-Likelihood:            -1.9263e+05
# No. Observations:               14959   AIC:                         3.854e+05
# Df Residuals:                   14874   BIC:                         3.861e+05
# Df Model:                          84
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept            -1.162e+05   2.35e+04     -4.934      0.000   -1.62e+05      -7e+04
# C(floors)[T.1.5]      4314.3447   3122.516      1.382      0.167   -1806.172    1.04e+04
# C(floors)[T.2.0]      4307.2813   2475.617      1.740      0.082    -545.234    9159.797
# C(floors)[T.2.5]       457.3883   1.11e+04      0.041      0.967   -2.13e+04    2.22e+04
# C(floors)[T.3.0]     -3.658e+04   5951.180     -6.147      0.000   -4.82e+04   -2.49e+04
# C(floors)[T.3.5]     -5.476e+04   4.27e+04     -1.281      0.200   -1.39e+05     2.9e+04
# C(waterfront)[T.1.0]  2.694e+05   1.53e+04     17.640      0.000    2.39e+05    2.99e+05
# C(condition)[T.2]     4.641e+04    2.4e+04      1.935      0.053    -613.749    9.34e+04
# C(condition)[T.3]     9.048e+04   2.26e+04      4.012      0.000    4.63e+04    1.35e+05
# C(condition)[T.4]     1.067e+05   2.26e+04      4.732      0.000    6.25e+04    1.51e+05
# C(condition)[T.5]     1.341e+05   2.27e+04      5.917      0.000    8.97e+04    1.79e+05
# C(has_basement)[T.1] -2.972e+04   1974.762    -15.050      0.000   -3.36e+04   -2.58e+04
# C(zipcode)[T.98002]  -4101.0989   9803.040     -0.418      0.676   -2.33e+04    1.51e+04
# C(zipcode)[T.98003]   1.437e+04   8761.393      1.641      0.101   -2799.462    3.15e+04
# C(zipcode)[T.98004]   5.494e+05   1.08e+04     50.724      0.000    5.28e+05    5.71e+05
# C(zipcode)[T.98178]   6.513e+04   9210.261      7.071      0.000    4.71e+04    8.32e+04
# C(zipcode)[T.98188]   3.128e+04   1.13e+04      2.758      0.006    9045.001    5.35e+04
# C(zipcode)[T.98198]   4.283e+04   8947.161      4.787      0.000    2.53e+04    6.04e+04
# C(zipcode)[T.98199]   3.928e+05   9223.776     42.585      0.000    3.75e+05    4.11e+05
# C(renovated)[T.1]     4.214e+04   4389.334      9.600      0.000    3.35e+04    5.07e+04
# sqft_living            159.7328      1.352    118.187      0.000     157.084     162.382
# sqft_lot                 0.3694      0.021     17.578      0.000       0.328       0.411
# age                   -162.9497     46.394     -3.512      0.000    -253.888     -72.012
# ==============================================================================
# Omnibus:                     1406.703   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4576.675
# Skew:                           0.476   Prob(JB):                         0.00
# Kurtosis:                       5.537   Cond. No.                     3.15e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.15e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model1.pvalues

pvals = model1.pvalues

pvals[pvals > 0.05]
# pvals[pvals > 0.05].index
# Out:
# C(floors)[T.1.5]      0.17
# C(floors)[T.2.0]      0.08
# C(floors)[T.2.5]      0.97
# C(floors)[T.3.5]      0.20
# C(condition)[T.2]     0.05
# C(zipcode)[T.98002]   0.68
# C(zipcode)[T.98003]   0.10
# C(zipcode)[T.98022]   0.14
# C(zipcode)[T.98023]   1.00
# C(zipcode)[T.98030]   0.30
# C(zipcode)[T.98032]   0.68
# C(zipcode)[T.98042]   0.14
# C(zipcode)[T.98092]   0.88
# dtype: float64

# %%
df = df.drop(['floors'], axis=1)

# %%
categoricals = [
#                 'bedrooms', 
#                 'bathrooms', 
#                 'floors', 
                'waterfront', 
                'condition', 
#                 'grade', 
                'has_basement',
                'zipcode',
                'renovated'
                ]

# %%
model1 = make_model(df, categoricals)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.791
# Model:                            OLS   Adj. R-squared:                  0.790
# Method:                 Least Squares   F-statistic:                     711.8
# Date:                Tue, 20 Apr 2021   Prob (F-statistic):               0.00
# Time:                        11:49:18   Log-Likelihood:            -1.9266e+05
# No. Observations:               14959   AIC:                         3.855e+05
# Df Residuals:                   14879   BIC:                         3.861e+05
# Df Model:                          79
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept             -1.22e+05   2.35e+04     -5.183      0.000   -1.68e+05   -7.59e+04
# C(waterfront)[T.1.0]  2.675e+05   1.53e+04     17.500      0.000    2.38e+05    2.97e+05
# C(condition)[T.2]      4.69e+04    2.4e+04      1.952      0.051    -201.732     9.4e+04
# C(condition)[T.3]     9.194e+04   2.26e+04      4.069      0.000    4.76e+04    1.36e+05
# C(condition)[T.4]     1.074e+05   2.26e+04      4.755      0.000    6.31e+04    1.52e+05
# C(condition)[T.5]     1.347e+05   2.27e+04      5.933      0.000    9.02e+04    1.79e+05
# C(has_basement)[T.1] -2.989e+04   1788.505    -16.711      0.000   -3.34e+04   -2.64e+04
# C(zipcode)[T.98002]  -4615.4043   9819.349     -0.470      0.638   -2.39e+04    1.46e+04
# C(zipcode)[T.98003]   1.365e+04   8775.715      1.556      0.120   -3548.628    3.09e+04
# C(zipcode)[T.98004]   5.457e+05   1.08e+04     50.367      0.000    5.24e+05    5.67e+05
+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
coeffs = model1.params
coeffs_list = coeffs.sort_values(ascending=False).round(2)

coeff_df = coeffs_list.to_frame()

# type(model1.params)
pd.options.display.max_rows = 999
coeff_df = coeff_df.reset_index()
coeff_df = coeff_df.rename(columns={'index': 'Variable', 0: 'Dollar Impact'})

# coeff_df['Dollar Impact'] = coeff_df['Dollar Impact'].apply(lambda x: "${:.2f}".format((x)))
coeff_df['Dollar Impact'] = coeff_df['Dollar Impact'].apply(lambda x: "{:,}".format(x))

coeff_df[~coeff_df['Variable'].str.contains("zipcode")]
# Out:
#                 Variable Dollar Impact
# 23  C(waterfront)[T.1.0]    267,481.28
# 41     C(condition)[T.5]     134,736.4
# 50     C(condition)[T.4]    107,431.92
# 53     C(condition)[T.3]     91,936.06
# 59     C(condition)[T.2]     46,903.32
# 63     C(renovated)[T.1]     41,109.12
# 73           sqft_living        161.71
# 74              sqft_lot          0.36
# 75                   age         -78.6
# 78  C(has_basement)[T.1]    -29,887.34
# 79             Intercept   -122,011.26

# %% [markdown]
# ## Observations
#
# Before looking at zipcode, let's take a look at our feature coefficients, which represent price impact.
#
# Waterfront is the most impactful, adding \\$267k to price.
#
# Condition lines up with our expectations.  The greater the condition, the more valuable the home.  Improving the condition from 1 to 5 would add an estimated \\$134,736.40 - \\$41,109.12 = \\$87,833.08 to a home owner's value.
#
# Renovated homes seem to fetch a larger price of approximately \\$41,109.12, which aligns with expectations.
#
# Sqft_living gives us an estimated value of \\$161.71 for every additional square foot of space.
#
# On the surface, sqft_lot looks like it has a relatively lower impact on price.  However, it is still relevant when comparing properties with significant differences in size.  One acre is 43,560 square feet.  Our model predicts that with a \\$0.36 impact to price for every square foot, an additional acre would add \\$15,681.60 to the value of two otherwise identical properties.
#
# Age doesn't seem to have a tangible impact.  Despite having a P-value greater than 0.05, a house will lose \\$78.60 in value.  Even in the case of our oldest houses, age can only have a maximum price impact of \\$9,039.
#
# Perhaps counterintuitively, the presence of a basement decreases the value of a home by \\$29,887.34.  This might require further examination.

# %%
print('Most valuable zip codes:')
print(coeff_df[coeff_df['Variable'].str.contains("zipcode")].head(5))
print('Least valuable zip codes:')
print(coeff_df[coeff_df['Variable'].str.contains("zipcode")].tail(5))
# Out:
# Most valuable zip codes:
#               Variable Dollar Impact
# 0  C(zipcode)[T.98039]    632,134.85
# 1  C(zipcode)[T.98004]    545,687.36
# 2  C(zipcode)[T.98112]    471,141.15
# 3  C(zipcode)[T.98040]    468,304.58
# 4  C(zipcode)[T.98119]    458,246.44
# Least valuable zip codes:
#                Variable Dollar Impact
# 70  C(zipcode)[T.98030]      9,673.59
# 71  C(zipcode)[T.98032]      3,161.96
# 72  C(zipcode)[T.98092]      2,240.83
# 76  C(zipcode)[T.98023]       -708.33
# 77  C(zipcode)[T.98002]      -4,615.4

# %% [markdown]
# Depending on the location, zip codes can have the most dramatic impact on price.  The most valuable zip codes are those closest to the metropolitan city center (Seattle, Bellevue, and Mercer Island).  The impact on price in the top 5 zip codes is an estimated \\$458-632k.
#
# Other than the two least valuable zip codes, our model functions in a way that doesn't subtract estimated value from homes.  The bottom 5 zip codes are located in Kent, near the southern end of King County.  While not the furthest from the city center, they are significantly further than our more valuable zip codes.

# %% [markdown]
# # iNTERPRET

# %% [markdown]
# Evaluate how well your work solves the stated business problem.
#
# ***
# Questions to consider:
# * How do you interpret the results?
# * How well does your model fit your data? How much better is this than your baseline model?
# * How confident are you that your results would generalize beyond the data you have?
# * How confident are you that this model would benefit the business if put into use?
# ***

# %% [markdown]
# # CONCLUSIONS & RECOMMENDATIONS

# %% [markdown]
# Provide your conclusions about the work you've done, including any limitations or next steps.
#
# ***
# Questions to consider:
# * What would you recommend the business do as a result of this work?
# * What are some reasons why your analysis might not fully solve the business problem?
# * What else could you do in the future to improve this project?
# ***

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# 1. **[OBTAIN](#OBTAIN)**
#     - Import data, inspect, check for datatypes to convert and null values
#     - Display header and info.
#     - Drop any unneeded columns, if known (`df.drop(['col1','col2'],axis=1,inplace=True`)
#     <br><br>
#
#
# 2. **[SCRUB](#SCRUB)**
#     - Recast data types, identify outliers, check for multicollinearity, normalize data**
#     - Check and cast data types
#         - [ ] Check for #'s that are store as objects (`df.info()`,`df.describe()`)
#             - when converting to #'s, look for odd values (like many 0's), or strings that can't be converted.
#             - Decide how to deal weird/null values (`df.unique()`, `df.isna().sum()`)
#             - `df.fillna(subset=['col_with_nulls'],'fill_value')`, `df.replace()`
#         - [ ] Check for categorical variables stored as integers.
#             - May be easier to tell when you make a scatter plotm or `pd.plotting.scatter_matrix()`
#
#     - [ ] Check for missing values  (df.isna().sum())
#         - Can drop rows or colums
#         - For missing numeric data with median or bin/convert to categorical
#         - For missing categorical data: make NaN own category OR replace with most common category
#     - [ ] Check for multicollinearity
#         - Use seaborn to make correlation matrix plot
#         - Good rule of thumb is anything over 0.75 corr is high, remove the variable that has the most correl with the largest # of variables
#     - [ ] Normalize data (may want to do after some exploring)
#         - Most popular is Z-scoring (but won't fix skew)
#         - Can log-transform to fix skewed data
#
#
# 3. **[EXPLORE](#EXPLORE)**
#     - [ ] Check distributions, outliers, etc**
#     - [ ] Check scales, ranges (df.describe())
#     - [ ] Check histograms to get an idea of distributions (df.hist()) and data transformations to perform.
#         - Can also do kernel density estimates
#     - [ ] Use scatter plots to check for linearity and possible categorical variables (`df.plot("x","y")`)
#         - categoricals will look like vertical lines
#     - [ ] Use `pd.plotting.scatter_matrix(df)` to visualize possible relationships
#     - [ ] Check for linearity.
#
#
# 4. **[MODEL](#MODEL)**
#
#     - **Fit an initial model:**
#         - Run an initial model and get results
#
#     - **Holdout validation / Train/test split**
#         - use sklearn `train_test_split`
#
#
# 5. **[iNTERPRET](#iNTERPRET)**
#     - **Assessing the model:**
#         - Assess parameters (slope,intercept)
#         - Check if the model explains the variation in the data (RMSE, F, R_square)
#         - *Are the coeffs, slopes, intercepts in appropriate units?*
#         - *Whats the impact of collinearity? Can we ignore?*
#         <br><br>
#     - **Revise the fitted model**
#         - Multicollinearity is big issue for lin regression and cannot fully remove it
#         - Use the predictive ability of model to test it (like R2 and RMSE)
#         - Check for missed non-linearity
#
#
# 6. **Interpret final model and draw >=3 conclusions and recommendations from dataset**
