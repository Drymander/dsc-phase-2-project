# %% [markdown]
# ## OVERVIEW OF OSEMiN

# %%
# def clean_column(column):
#     column_str = str(column)
#     print('Total unique itms: ' + str(df[column].nunique()))
#     print('Displaying first 10:')
#     print(df[column].unique()[0:10])
#     return column_str

# # print(check_column(date))

# check_column('date')

# # column = 'date'

# # print('Total unique itms: ' + str(df[column].nunique()))

# %%
# print('Total unique itms: ' + str(df['date'].nunique()))
# print('Displaying first 10:')
# print(df['date'].unique()[0:10])

# sns.regplot(data=df, x='sqft_living', y='price')

# # try: 
# #     sns.regplot(data=df, x='date', y='price')
# # except:
# #     print('regplot did not work')
# # try: 
# #     sns.displot(data=df, x='date', y='price')
# # except:
# #     print('regplot did not work')

# %%
# pip install jupyter_contrib_nbextensions

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jirvingphd/fsds_100719_cohort_notes/master/images/OSEMN.png' width=800>
#
# <center><a href="https://www.kdnuggets.com/2018/02/data-science-command-line-book-exploring-data.html">
#     </a></center>
#
#
# > <font size=2em>The Data Science Process we'll be using during this section--OSEMiN (pronounced "OH-sum", rhymes with "possum").  This is the most straightforward of the Data Science Processes discussed so far.  **Note that during this process, just like the others, the stages often blur together.***  It is completely acceptable (and ***often a best practice!) to float back and forth** between stages as you learn new things about your problem, dataset, requirements, etc.
# It's quite common to get to the modeling step and realize that you need to scrub your data a bit more or engineer a different feature and jump back to the "Scrub" stage, or go all the way back to the "Obtain" stage when you realize your current data isn't sufficient to solve this problem.
# As with any of these frameworks, *OSEMiN is meant to be treated as guidelines, not law.
# </font>
#
#
# ### OSEMN DETAILS
#
# **OBTAIN**
#
# - This step involves understanding stakeholder requirements, gathering information on the problem, and finally sourcing data that we think will be necessary for solving this problem.
#
# **SCRUB**
#
# - During this stage, we'll focus on preprocessing our data.  Important steps such as identifying and removing null values, dealing with outliers, normalizing data, and feature engineering/feature selection are handled around this stage.  The line with this stage really blurs with the _Explore_ stage, as it is common to only realize that certain columns require cleaning or preprocessing as a result of the visualzations and explorations done during Step 3.
#
# - Note that although technically, categorical data should be one-hot encoded during this step, in practice, it's usually done after data exploration.  This is because it is much less time-consuming to visualize and explore a few columns containing categorical data than it is to explore many different dummy columns that have been one-hot encoded.
#
# **EXPLORE**
#
# - This step focuses on getting to know the dataset you're working with. As mentioned above, this step tends to blend with the _Scrub_ step mentioned above.  During this step, you'll create visualizations to really get a feel for your dataset.  You'll focus on things such as understanding the distribution of different columns, checking for multicollinearity, and other tasks liek that.  If your project is a classification task, you may check the balance of the different classes in your dataset.  If your problem is a regression task, you may check that the dataset meets the assumptions necessary for a regression task.
#
# - At the end of this step, you should have a dataset ready for modeling that you've thoroughly explored and are extremely familiar with.
#
# **MODEL**
#
# - This step, as with the last two frameworks, is also pretty self-explanatory. It consists of building and tuning models using all the tools you have in your data science toolbox.  In practice, this often means defining a threshold for success, selecting machine learning algorithms to test on the project, and tuning the ones that show promise to try and increase your results.  As with the other stages, it is both common and accepted to realize something, jump back to a previous stage like _Scrub_ or _Explore_, and make some changes to see how it affects the model.
#
# **iNTERPRET**
#
# - During this step, you'll interpret the results of your model(s), and communicate results to stakeholders.  As with the other frameworks, communication is incredibily important! During this stage, you may come to realize that further investigation is needed, or more data.  That's totally fine--figure out what's needed, go get it, and start the process over! If your results are satisfactory to all stakeholders involved, you may also go from this stage right into productionizing your model and automating processes necessary to support it.

# %% [markdown]
# ## PROCESS CHECKLIST

# %% [markdown]
# > Keep in mind that it is normal to jump between the OSEMN phases and some of them will blend together, like SCRUB and EXPLORE.

# %% [markdown]
# 1. **[OBTAIN](#OBTAIN)**
#     - Import data, inspect, check for datatypes to convert and null values
#     - Display header and info.
#     - Drop any unneeded columns, if known (`df.drop(['col1','col2'],axis=1,inplace=True`)
#     <br><br>
#
#
# 2. **[SCRUB](#SCRUB)**
#     - Recast data types, identify outliers, check for multicollinearity, normalize data**
#     - Check and cast data types
#         - [ ] Check for #'s that are store as objects (`df.info()`,`df.describe()`)
#             - when converting to #'s, look for odd values (like many 0's), or strings that can't be converted.
#             - Decide how to deal weird/null values (`df.unique()`, `df.isna().sum()`)
#             - `df.fillna(subset=['col_with_nulls'],'fill_value')`, `df.replace()`
#         - [ ] Check for categorical variables stored as integers.
#             - May be easier to tell when you make a scatter plotm or `pd.plotting.scatter_matrix()`
#
#     - [ ] Check for missing values  (df.isna().sum())
#         - Can drop rows or colums
#         - For missing numeric data with median or bin/convert to categorical
#         - For missing categorical data: make NaN own category OR replace with most common category
#     - [ ] Check for multicollinearity
#         - Use seaborn to make correlation matrix plot
#         - Good rule of thumb is anything over 0.75 corr is high, remove the variable that has the most correl with the largest # of variables
#     - [ ] Normalize data (may want to do after some exploring)
#         - Most popular is Z-scoring (but won't fix skew)
#         - Can log-transform to fix skewed data
#
#
# 3. **[EXPLORE](#EXPLORE)**
#     - [ ] Check distributions, outliers, etc**
#     - [ ] Check scales, ranges (df.describe())
#     - [ ] Check histograms to get an idea of distributions (df.hist()) and data transformations to perform.
#         - Can also do kernel density estimates
#     - [ ] Use scatter plots to check for linearity and possible categorical variables (`df.plot("x","y")`)
#         - categoricals will look like vertical lines
#     - [ ] Use `pd.plotting.scatter_matrix(df)` to visualize possible relationships
#     - [ ] Check for linearity.
#
#
# 4. **[MODEL](#MODEL)**
#
#     - **Fit an initial model:**
#         - Run an initial model and get results
#
#     - **Holdout validation / Train/test split**
#         - use sklearn `train_test_split`
#
#
# 5. **[iNTERPRET](#iNTERPRET)**
#     - **Assessing the model:**
#         - Assess parameters (slope,intercept)
#         - Check if the model explains the variation in the data (RMSE, F, R_square)
#         - *Are the coeffs, slopes, intercepts in appropriate units?*
#         - *Whats the impact of collinearity? Can we ignore?*
#         <br><br>
#     - **Revise the fitted model**
#         - Multicollinearity is big issue for lin regression and cannot fully remove it
#         - Use the predictive ability of model to test it (like R2 and RMSE)
#         - Check for missed non-linearity
#
#
# 6. **Interpret final model and draw >=3 conclusions and recommendations from dataset**

# %% [markdown]
# <div style="display:block;border-bottom:solid red 3px;padding:1.4em;color:red;font-size:30pt;display:inline-block;line-height:1.5em;">
# DELETE THIS CELL AND EVERYTHING ABOVE FROM YOUR FINAL NOTEBOOK
# </div>

# %% [markdown]
# # Final Project Submission

# %% [markdown]
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time:
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:
# * Video of 5-min Non-Technical Presentation:

# %% [markdown]
# ## TABLE OF CONTENTS

# %% [markdown]
# *Click to jump to matching Markdown Header.*<br><br>
#
# - **[Introduction](#INTRODUCTION)<br>**
# - **[OBTAIN](#OBTAIN)**<br>
# - **[SCRUB](#SCRUB)**<br>
# - **[EXPLORE](#EXPLORE)**<br>
# - **[MODEL](#MODEL)**<br>
# - **[iNTERPRET](#iNTERPRET)**<br>
# - **[Conclusions/Recommendations](#CONCLUSIONS-&-RECOMMENDATIONS)<br>**
# ___

# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# > Explain the point of your project and what question you are trying to answer with your modeling.
#
# ## Business Problem
#
# Summary of the business problem you are trying to solve, and the data questions that you plan to answer to solve them.
#
# ***
# Questions to consider:
# * What are the business's pain points related to this project?
# * How did you pick the data analysis question(s) that you did?
# * Why are these questions important from a business perspective?
# ***

# %% [markdown]
# # OBTAIN

# %% [markdown]
# ## Data Understanding
#
# Describe the data being used for this project.
# ***
# Questions to consider:
# * Where did the data come from, and how do they relate to the data analysis questions?
# * What do the data represent? Who is in the sample and what variables are included?
# * What is the target variable?
# * What are the properties of the variables you intend to use?
# ***

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('data/kc_house_data.csv')

df.columns

#which ones have a linear relationship to price.  funciton that did two things, plot distribtuion plot of column
#as one sup plot, then one between reg column and target column, 
#if more skewed, normalize might be worth considering.

# plot show feature vs price

# plot show distribution
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# # SCRUB

# %% [markdown]
# ## Data Preparation
#
# Describe and justify the process for preparing the data for analysis.
#
# ***
# Questions to consider:
# * Were there variables you dropped or created?
# * How did you address missing values or outliers?
# * Why are these choices appropriate given the data and the business problem?
# ***

# %%
df.head()

print(df.info())

print(df.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
#  17  lat            21597 non-null  float64
#  18  long           21597 non-null  float64
#  19  sqft_living15  21597 non-null  int64
#  20  sqft_lot15     21597 non-null  int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB
# None
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
df = df.set_index('id')

# %%
import missingno as msno

msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
def clean_column(column, unique_count=10):
    column_str = str(column)
    print('Datatype: ' + str(df[column].dtypes))
    print('Total unique itms: ' + str(df[column].nunique()))
    print('Displaying first ' + str(unique_count) + ':')
    print(df[column].unique()[0:unique_count])
    return column_str

# %%
clean_column('waterfront')

# this code assigns 0 to all na waterfronts.  will not use
# df['waterfront'] = df['waterfront'].fillna(0)
# df['waterfront'] = df['waterfront'].astype(int)

df = df[df['waterfront'].notna()]

clean_column('waterfront')
# Out:
# Datatype: float64
# Total unique itms: 2
# Displaying first 10:
# [nan  0.  1.]
# Datatype: float64
# Total unique itms: 2
# Displaying first 10:
# [0. 1.]
# 'waterfront'

# %%
clean_column('view')

df['view'] = df['view'].fillna(0)
df['view'] = df['view'].astype(int)

clean_column('view')
# Out:
# Datatype: float64
# Total unique itms: 5
# Displaying first 10:
# [ 0. nan  3.  4.  2.  1.]
# Datatype: int32
# Total unique itms: 5
# Displaying first 10:
# [0 3 4 2 1]
# 'view'

# %%
clean_column('yr_renovated', unique_count=100)
# Out:
# Datatype: float64
# Total unique itms: 70
# Displaying first 100:
# [1991.   nan    0. 2002. 2010. 1992. 2013. 1994. 1978. 2005. 2003. 1984.
#  1954. 2014. 2011. 1983. 1990. 1988. 1977. 1981. 1995. 2000. 1999. 1998.
#  1970. 1989. 2004. 1986. 2007. 1987. 2006. 1985. 2001. 1980. 1971. 1945.
#  1979. 1997. 1950. 1969. 1948. 2009. 2015. 2008. 2012. 1968. 1963. 1951.
#  1962. 1953. 1993. 1955. 1996. 1982. 1956. 1940. 1976. 1946. 1975. 1964.
#  1973. 1957. 1959. 1960. 1965. 1967. 1934. 1972. 1944. 1958. 1974.]
# 'yr_renovated'

# %% [markdown]
# We will first remove rows with nan values from the dataset.

# %%
df = df[df['yr_renovated'].notna()]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15809 entries, 6414100192 to 1523300157
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           15809 non-null  object
#  1   price          15809 non-null  float64
#  2   bedrooms       15809 non-null  int64
#  3   bathrooms      15809 non-null  float64
#  4   sqft_living    15809 non-null  int64
#  5   sqft_lot       15809 non-null  int64
#  6   floors         15809 non-null  float64
#  7   waterfront     15809 non-null  float64
#  8   view           15809 non-null  int32
#  9   condition      15809 non-null  int64
#  10  grade          15809 non-null  int64
#  11  sqft_above     15809 non-null  int64
#  12  sqft_basement  15809 non-null  object
#  13  yr_built       15809 non-null  int64
#  14  yr_renovated   15809 non-null  float64
#  15  zipcode        15809 non-null  int64
#  16  lat            15809 non-null  float64
#  17  long           15809 non-null  float64
#  18  sqft_living15  15809 non-null  int64
#  19  sqft_lot15     15809 non-null  int64
# dtypes: float64(7), int32(1), int64(10), object(2)
# memory usage: 2.5+ MB

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
ren_df = df[df['yr_renovated'] != 0]

not_ren_df = df[df['yr_renovated'] == 0]

# %%
ren_df['price'].describe()
# Out:
# count       652.00
# mean     762021.03
# std      637336.70
# min      110000.00
# 25%      410000.00
# 50%      600000.00
# 75%      890250.00
# max     7700000.00
# Name: price, dtype: float64

# %%
not_ren_df['price'].describe()
# Out:
# count     15157.00
# mean     532063.36
# std      355257.77
# min       82000.00
# 25%      320000.00
# 50%      449000.00
# 75%      633000.00
# max     6890000.00
# Name: price, dtype: float64

# %% [markdown]
# Differences are significant, will move forward with binary.

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Now we'll take a look at each column and see if anything needs correction.

# %% [markdown]
# ## list

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15809 entries, 6414100192 to 1523300157
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           15809 non-null  object
#  1   price          15809 non-null  float64
#  2   bedrooms       15809 non-null  int64
#  3   bathrooms      15809 non-null  float64
#  4   sqft_living    15809 non-null  int64
#  5   sqft_lot       15809 non-null  int64
#  6   floors         15809 non-null  float64
#  7   waterfront     15809 non-null  float64
#  8   view           15809 non-null  int32
#  9   condition      15809 non-null  int64
#  10  grade          15809 non-null  int64
#  11  sqft_above     15809 non-null  int64
#  12  sqft_basement  15809 non-null  object
#  13  yr_built       15809 non-null  int64
#  14  yr_renovated   15809 non-null  float64
#  15  zipcode        15809 non-null  int64
#  16  lat            15809 non-null  float64
#  17  long           15809 non-null  float64
#  18  sqft_living15  15809 non-null  int64
#  19  sqft_lot15     15809 non-null  int64
# dtypes: float64(7), int32(1), int64(10), object(2)
# memory usage: 2.5+ MB
# None

# %%
df.head()
# Out:
#                  date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 6414100192  12/9/2014  538000.00         3       2.25         2570      7242
# 2487200875  12/9/2014  604000.00         4       3.00         1960      5000
# 1954400510  2/18/2015  510000.00         3       2.00         1680      8080
# 7237550310  5/12/2014 1230000.00         4       4.50         5420    101930
# 1321400060  6/27/2014  257500.00         3       2.25         1715      6819
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 6414100192    2.00        0.00     0          3      7        2170
# 2487200875    1.00        0.00     0          5      7        1050
# 1954400510    1.00        0.00     0          3      8        1680
# 7237550310    1.00        0.00     0          3     11        3890
# 1321400060    2.00        0.00     0          3      7        1715
#
#            sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# id
# 6414100192         400.0      1951       1991.00    98125 47.72 -122.32
# 2487200875         910.0      1965          0.00    98136 47.52 -122.39
# 1954400510           0.0      1987          0.00    98074 47.62 -122.05
# 7237550310        1530.0      2001          0.00    98053 47.66 -122.00
# 1321400060             ?      1995          0.00    98003 47.31 -122.33
#
#             sqft_living15  sqft_lot15
# id
# 6414100192           1690        7639
# 2487200875           1360        5000
# 1954400510           1800        7503
# 7237550310           4760      101930
# 1321400060           2238        6819

# %%
def clean_column(column, unique_count=10):
    column_str = str(column)
    print('Datatype: ' + str(df[column].dtypes))
    print('Total unique itms: ' + str(df[column].nunique()))
    print('Displaying first ' + str(unique_count) + ':')
    print(df[column].unique()[0:unique_count])
    print(f"Minimum value: {df[column].min()}.  Maximum value: {df[column].max()}")
    print(df[column].describe())
    return column_str

def regplot(column, df=df):
    return sns.regplot(data=df, x=column, y='price')
    
def hist(column):
    hist = df[column].hist()
    return plt.show()

def displot(column):
    return sns.displot(data=df, x=column, y='price')

# %% [markdown]
# ## Date

# %%
clean_column('date')

df['bedrooms'].describe()
# Out:
# Datatype: object
# Total unique itms: 370
# Displaying first 10:
# ['12/9/2014' '2/18/2015' '5/12/2014' '6/27/2014' '1/15/2015' '4/15/2015'
#  '3/12/2015' '5/27/2014' '10/7/2014' '1/24/2015']
# Minimum value: 1/10/2015.  Maximum value: 9/9/2014
# count         15809
# unique          370
# top       6/25/2014
# freq            103
# Name: date, dtype: object
# count   15809.00
# mean        3.38
# std         0.94
# min         1.00
# 25%         3.00
# 50%         3.00
# 75%         4.00
# max        33.00
# Name: bedrooms, dtype: float64

# %%
df['date'] = df['date'].apply(pd.to_datetime)

# %%
df['date'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Bedrooms

# %%
clean_column('bedrooms', unique_count=20)
# Out:
# Datatype: int64
# Total unique itms: 12
# Displaying first 20:
# [ 3  4  2  5  1  6  7  8  9 11 10 33]
# Minimum value: 1.  Maximum value: 33
# count   15809.00
# mean        3.38
# std         0.94
# min         1.00
# 25%         3.00
# 50%         3.00
# 75%         4.00
# max        33.00
# Name: bedrooms, dtype: float64
# 'bedrooms'

# %%
displot('bedrooms')

# %%
df.loc[df['bedrooms'] == 33]
# Out:
#                  date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 2402100895 2014-06-25 640000.00        33       1.75         1620      6000
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 2402100895    1.00        0.00     0          5      7        1040
#
#            sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# id
# 2402100895         580.0      1947          0.00    98103 47.69 -122.33
#
#             sqft_living15  sqft_lot15
# id
# 2402100895           1330        4700

# %% [markdown]
# Based on other stats, we assume the one entry with 33 bedrooms to actually be 3 bedrooms.  Correcting below.

# %%
df['bedrooms'] = df['bedrooms'].replace([33],3)

df.loc[df['bedrooms'] == 33]
# Out:
# Empty DataFrame
# Columns: [date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []

# %%
df.loc[df['bedrooms'] == 11]
# Out:
#                  date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 1773100755 2014-08-21 520000.00        11       3.00         3000      4960
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 1773100755    2.00        0.00     0          3      7        2400
#
#            sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# id
# 1773100755         600.0      1918       1999.00    98106 47.56 -122.36
#
#             sqft_living15  sqft_lot15
# id
# 1773100755           1420        4960

# %% [markdown]
# The 11 bedroom house also seems unlikely based on square footage.  Googling the ID '1773100755' revelas it to be a 4 bedroom house.

# %%
df['bedrooms'] = df['bedrooms'].replace([11],4)

df.loc[df['bedrooms'] == 11]
# Out:
# Empty DataFrame
# Columns: [date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []

# %%
df.loc[df['bedrooms'] == 10]
# Out:
#                  date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 627300145  2014-08-14 1150000.00        10       5.25         4590     10920
# 5566100170 2014-10-29  650000.00        10       2.00         3610     11914
# 8812401450 2014-12-29  660000.00        10       3.00         2920      3745
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 627300145     1.00        0.00     2          3      9        2500
# 5566100170    2.00        0.00     0          4      7        3010
# 8812401450    2.00        0.00     0          4      7        1860
#
#            sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# id
# 627300145         2090.0      2008          0.00    98004 47.59 -122.11
# 5566100170         600.0      1958          0.00    98006 47.57 -122.17
# 8812401450        1060.0      1913          0.00    98105 47.66 -122.32
#
#             sqft_living15  sqft_lot15
# id
# 627300145            2730       10400
# 5566100170           2040       11914
# 8812401450           1810        3745

# %% [markdown]
# Even though two of the 10 bedroom houses seem unlikely, a quick google shows that they are recorded as 9 bedroom houses on zillow.  We will assume these entries were accurate at the time, and will not change.

# %% [markdown]
# ## Bathrooms

# %%
clean_column('bathrooms', unique_count=29)
# Out:
# Datatype: float64
# Total unique itms: 27
# Displaying first 29:
# [2.25 3.   2.   4.5  1.5  1.   2.5  1.75 2.75 3.25 4.   3.5  0.75 5.
#  4.25 3.75 1.25 5.25 6.   4.75 0.5  5.5  5.75 8.   6.75 7.5  7.75]
# Minimum value: 0.5.  Maximum value: 8.0
# count   15809.00
# mean        2.12
# std         0.77
# min         0.50
# 25%         1.75
# 50%         2.25
# 75%         2.50
# max         8.00
# Name: bathrooms, dtype: float64
# 'bathrooms'

# %%
hist('bathrooms')

# %%
regplot('bathrooms')
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='price'>

# %% [markdown]
# ## Squarefoot - Living

# %%
clean_column('sqft_living')
# Out:
# Datatype: int64
# Total unique itms: 913
# Displaying first 10:
# [2570 1960 1680 5420 1715 1060 1780 1890 1160 1370]
# Minimum value: 370.  Maximum value: 13540
# count   15809.00
# mean     2084.96
# std       919.48
# min       370.00
# 25%      1430.00
# 50%      1920.00
# 75%      2550.00
# max     13540.00
# Name: sqft_living, dtype: float64
# 'sqft_living'

# %%
regplot('sqft_living')
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
hist('sqft_living')

# %% [markdown]
# There seem to be at least one unusual outlier for the price.  We will want to take a look at the largest values to verify the quality of the data.

# %%
df.sort_values(by=['sqft_living'], ascending=False).head(5)
# Out:
#                  date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 1225069038 2014-05-05 2280000.00         7       8.00        13540    307752
# 6762700020 2014-10-13 7700000.00         6       8.00        12050     27600
# 9808700762 2014-06-11 7060000.00         5       4.50        10040     37325
# 9208900037 2014-09-19 6890000.00         6       7.75         9890     31374
# 1924059029 2014-06-17 4670000.00         5       6.75         9640     13068
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 1225069038    3.00        0.00     4          3     12        9410
# 6762700020    2.50        0.00     3          4     13        8570
# 9808700762    2.00        1.00     2          3     11        7680
# 9208900037    2.00        0.00     4          3     13        8860
# 1924059029    1.00        1.00     4          3     12        4820
#
#            sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# id
# 1225069038        4130.0      1999          0.00    98053 47.67 -121.99
# 6762700020        3480.0      1910       1987.00    98102 47.63 -122.32
# 9808700762        2360.0      1940       2001.00    98004 47.65 -122.21
# 9208900037        1030.0      2001          0.00    98039 47.63 -122.24
# 1924059029        4820.0      1983       2009.00    98040 47.56 -122.21
#
#             sqft_living15  sqft_lot15
# id
# 1225069038           4850      217800
# 6762700020           3940        8800
# 9808700762           3930       25449
# 9208900037           4540       42730
# 1924059029           3270       10454

# %% [markdown]
# After reviewing the one outlier, it seems to be a compound in a rural area, and the sqft seems realistic.

# %% [markdown]
# ## Squarefoot - Lot

# %%
clean_column('sqft_lot')
regplot('sqft_lot')
# Out:
# Datatype: int64
# Total unique itms: 7939
# Displaying first 10:
# [  7242   5000   8080 101930   6819   9711   7470   6560   6000   9680]
# Minimum value: 520.  Maximum value: 1651359
# count     15809.00
# mean      15298.23
# std       41884.56
# min         520.00
# 25%        5053.00
# 50%        7605.00
# 75%       10716.00
# max     1651359.00
# Name: sqft_lot, dtype: float64
# <AxesSubplot:xlabel='sqft_lot', ylabel='price'>

# %%
hist('sqft_lot')

# %%
df.sort_values(by=['sqft_lot'], ascending=False).head(5)

#outlier looks like a farm, will keep
# Out:
#                  date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 1020069017 2015-03-27 700000.00         4       1.00         1300   1651359
# 3326079016 2015-05-04 190000.00         2       1.00          710   1164794
# 2323089009 2015-01-19 855000.00         4       3.50         4030   1024068
# 722069232  2014-09-05 998000.00         4       3.25         3770    982998
# 3626079040 2014-07-30 790000.00         2       3.00         2560    982278
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 1020069017    1.00        0.00     3          4      6        1300
# 3326079016    1.00        0.00     0          2      5         710
# 2323089009    2.00        0.00     0          3     10        4030
# 722069232     2.00        0.00     0          3     10        3770
# 3626079040    1.00        0.00     0          3      8        2560
#
#            sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# id
# 1020069017           0.0      1920          0.00    98022 47.23 -122.02
# 3326079016           0.0      1915          0.00    98014 47.69 -121.91
# 2323089009           0.0      2006          0.00    98045 47.46 -121.74
# 722069232            0.0      1992          0.00    98058 47.41 -122.09
# 3626079040           0.0      2004          0.00    98014 47.70 -121.86
#
#             sqft_living15  sqft_lot15
# id
# 1020069017           2560      425581
# 3326079016           1680       16730
# 2323089009           1830       11700
# 722069232            2290       37141
# 3626079040           1620       40946

# %% [markdown]
# ## Floors

# %%
clean_column('floors')

regplot('floors')
# Out:
# Datatype: float64
# Total unique itms: 6
# Displaying first 10:
# [2.  1.  1.5 3.  2.5 3.5]
# Minimum value: 1.0.  Maximum value: 3.5
# count   15809.00
# mean        1.49
# std         0.54
# min         1.00
# 25%         1.00
# 50%         1.50
# 75%         2.00
# max         3.50
# Name: floors, dtype: float64
# <AxesSubplot:xlabel='floors', ylabel='price'>

# %%
hist('floors')

# %% [markdown]
# ## Waterfront

# %%
clean_column('waterfront')

regplot('waterfront')
# Out:
# Datatype: float64
# Total unique itms: 2
# Displaying first 10:
# [0. 1.]
# Minimum value: 0.0.  Maximum value: 1.0
# count   15809.00
# mean        0.01
# std         0.09
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max         1.00
# Name: waterfront, dtype: float64
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
hist('waterfront')

# %% [markdown]
# ## View

# %%
clean_column('view')

regplot('view')
# Out:
# Datatype: int32
# Total unique itms: 5
# Displaying first 10:
# [0 3 4 2 1]
# Minimum value: 0.  Maximum value: 4
# count   15809.00
# mean        0.23
# std         0.76
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max         4.00
# Name: view, dtype: float64
# <AxesSubplot:xlabel='view', ylabel='price'>

# %% [markdown]
# ## condition

# %%
clean_column('condition')

regplot('condition')
# Out:
# Datatype: int64
# Total unique itms: 5
# Displaying first 10:
# [3 5 4 1 2]
# Minimum value: 1.  Maximum value: 5
# count   15809.00
# mean        3.41
# std         0.65
# min         1.00
# 25%         3.00
# 50%         3.00
# 75%         4.00
# max         5.00
# Name: condition, dtype: float64
# <AxesSubplot:xlabel='condition', ylabel='price'>

# %%
hist('condition')

# %% [markdown]
# ## grade

# %%
clean_column('grade')

regplot('grade')
# Out:
# Datatype: int64
# Total unique itms: 11
# Displaying first 10:
# [ 7  8 11  9  6  5 10 12  4  3]
# Minimum value: 3.  Maximum value: 13
# count   15809.00
# mean        7.66
# std         1.17
# min         3.00
# 25%         7.00
# 50%         7.00
# 75%         8.00
# max        13.00
# Name: grade, dtype: float64
# <AxesSubplot:xlabel='grade', ylabel='price'>

# %%
hist('grade')

# %%
df[df['grade'] == 13]
# Out:
#                  date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 9831200500 2015-03-04 2480000.00         5       3.75         6810      7500
# 7237501190 2014-10-10 1780000.00         4       3.25         4890     13402
# 1725059316 2014-11-20 2390000.00         4       4.00         6330     13296
# 853200010  2014-07-01 3800000.00         5       5.50         7050     42840
# 6762700020 2014-10-13 7700000.00         6       8.00        12050     27600
# 1068000375 2014-09-23 3200000.00         6       5.00         7100     18200
# 9208900037 2014-09-19 6890000.00         6       7.75         9890     31374
# 3303850390 2014-12-12 2980000.00         5       5.50         7400     18898
# 2426039123 2015-01-30 2420000.00         5       4.75         7880     24250
# 4139900180 2015-04-20 2340000.00         4       2.50         4500     35200
# 2303900100 2014-09-11 3800000.00         3       4.25         5510     35000
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 9831200500    2.50        0.00     0          3     13        6110
# 7237501190    2.00        0.00     0          3     13        4890
# 1725059316    2.00        0.00     2          3     13        4900
# 853200010     1.00        0.00     2          4     13        4320
# 6762700020    2.50        0.00     3          4     13        8570
# 1068000375    2.50        0.00     0          3     13        5240
# 9208900037    2.00        0.00     4          3     13        8860
# 3303850390    2.00        0.00     3          3     13        6290
# 2426039123    2.00        0.00     2          3     13        7880
# 4139900180    1.00        0.00     0          3     13        4500
# 2303900100    2.00        0.00     4          3     13        4910
#
#            sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# id
# 9831200500         700.0      1922          0.00    98102 47.63 -122.32
# 7237501190           0.0      2004          0.00    98059 47.53 -122.13
# 1725059316        1430.0      2000          0.00    98033 47.65 -122.20
# 853200010         2730.0      1978          0.00    98004 47.62 -122.22
# 6762700020        3480.0      1910       1987.00    98102 47.63 -122.32
# 1068000375        1860.0      1933       2002.00    98199 47.64 -122.41
# 9208900037        1030.0      2001          0.00    98039 47.63 -122.24
# 3303850390        1110.0      2001          0.00    98006 47.54 -122.11
# 2426039123           0.0      1996          0.00    98177 47.73 -122.36
# 4139900180           0.0      1988          0.00    98006 47.55 -122.13
# 2303900100         600.0      1997          0.00    98177 47.73 -122.37
#
#             sqft_living15  sqft_lot15
# id
# 9831200500           2660        7500
# 7237501190           5790       13539
# 1725059316           2200        9196
# 853200010            5070       20570
# 6762700020           3940        8800
# 1068000375           3130        6477
# 9208900037           4540       42730
# 3303850390           6110       26442
# 2426039123           2740       10761
# 4139900180           4760       35200
# 2303900100           3430       45302

# %% [markdown]
# ## sqft_above

# %%
clean_column('sqft_above')

regplot('sqft_above')
# Out:
# Datatype: int64
# Total unique itms: 835
# Displaying first 10:
# [2170 1050 1680 3890 1715 1060 1890  860 1370 1810]
# Minimum value: 370.  Maximum value: 9410
# count   15809.00
# mean     1792.75
# std       828.48
# min       370.00
# 25%      1200.00
# 50%      1570.00
# 75%      2220.00
# max      9410.00
# Name: sqft_above, dtype: float64
# <AxesSubplot:xlabel='sqft_above', ylabel='price'>

# %%
hist('sqft_above')

# %% [markdown]
# ## sqft_basement

# %%
clean_column('sqft_basement')
# Out:
# Datatype: object
# Total unique itms: 285
# Displaying first 10:
# ['400.0' '910.0' '0.0' '1530.0' '?' '730.0' '300.0' '970.0' '760.0'
#  '720.0']
# Minimum value: 0.0.  Maximum value: ?
# count     15809
# unique      285
# top         0.0
# freq       9384
# Name: sqft_basement, dtype: object
# 'sqft_basement'

# %% [markdown]
# It seems there are some errors with question marks.  Let's take a look.

# %%
df[df['sqft_basement'] == '?']
# Out:
#                  date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 1321400060 2014-06-27 257500.00         3       2.25         1715      6819
# 16000397   2014-12-05 189000.00         2       1.00         1200      9850
# 7203220400 2014-07-07 861990.00         5       2.75         3595      5639
# 1531000030 2015-03-23 720000.00         4       2.50         3450     39683
# 2525310310 2014-09-16 272500.00         3       1.75         1540     12600
# ...               ...       ...       ...        ...          ...       ...
# 3278600680 2014-06-27 235000.00         1       1.50         1170      1456
# 2309710150 2014-08-04 325000.00         4       3.25         2800      5291
# 9521100301 2014-05-07 339950.00         2       1.00          820       681
# 3226049565 2014-07-11 504600.00         5       3.00         2360      5000
# 2909310100 2014-10-15 332000.00         4       2.50         2380      5737
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 1321400060    2.00        0.00     0          3      7        1715
# 16000397      1.00        0.00     0          4      7        1200
# 7203220400    2.00        0.00     0          3      9        3595
# 1531000030    2.00        0.00     0          3     10        3450
# 2525310310    1.00        0.00     0          4      7        1160
# ...            ...         ...   ...        ...    ...         ...
# 3278600680    2.00        0.00     0          3      8        1070
# 2309710150    2.00        0.00     0          3      7        2800
# 9521100301    3.00        0.00     0          3      8         820
# 3226049565    1.00        0.00     0          3      7        1390
# 2909310100    2.00        0.00     0          3      7        2380
#
#            sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# id
# 1321400060             ?      1995          0.00    98003 47.31 -122.33
# 16000397               ?      1921          0.00    98002 47.31 -122.21
# 7203220400             ?      2014          0.00    98053 47.68 -122.02
# 1531000030             ?      2002          0.00    98010 47.34 -122.03
# 2525310310             ?      1980          0.00    98038 47.36 -122.03
# ...                  ...       ...           ...      ...   ...     ...
# 3278600680             ?      2007          0.00    98126 47.55 -122.37
# 2309710150             ?      2011          0.00    98022 47.19 -121.98
# 9521100301             ?      2006          0.00    98103 47.66 -122.35
# 3226049565             ?      2008          0.00    98103 47.69 -122.33
# 2909310100             ?      2010          0.00    98023 47.28 -122.36
#
#             sqft_living15  sqft_lot15
# id
# 1321400060           2238        6819
# 16000397             1060        5095
# 7203220400           3625        5639
# 1531000030           3350       39750
# 2525310310           1540       11656
# ...                   ...         ...
# 3278600680           1360        1730
# 2309710150           2380        5291
# 9521100301            820        1156
# 3226049565           2180        5009
# 2909310100           2380        5396
#
# [335 rows x 20 columns]

# %% [markdown]
# It might be best to go ahead and make a "True" and "False" boolean column for 'has_basement.'  We will also change all '?' values to zero (0) and conver the values into floats.

# %%
# df['sqft_basement'] = df['sqft_basement'].replace(['?'],0.0)

df['sqft_basement'] = df['sqft_living'] - df['sqft_above']

df.loc[df['sqft_basement'] == '?']
# Out:
# Empty DataFrame
# Columns: [date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []

# %%
df['sqft_basement'] = df['sqft_basement'].astype(float)

# %%
# run this line if need to rerun and delete 'has_basement'
# del df['has_basement']

has_basement = np.where(df['sqft_basement'] > 0, 1, 0)

df.insert (12, 'has_basement', has_basement)

df.head(5)
# Out:
#                  date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 6414100192 2014-12-09  538000.00         3       2.25         2570      7242
# 2487200875 2014-12-09  604000.00         4       3.00         1960      5000
# 1954400510 2015-02-18  510000.00         3       2.00         1680      8080
# 7237550310 2014-05-12 1230000.00         4       4.50         5420    101930
# 1321400060 2014-06-27  257500.00         3       2.25         1715      6819
#
#             floors  waterfront  view  condition  ...  sqft_above  \
# id                                               ...
# 6414100192    2.00        0.00     0          3  ...        2170
# 2487200875    1.00        0.00     0          5  ...        1050
# 1954400510    1.00        0.00     0          3  ...        1680
# 7237550310    1.00        0.00     0          3  ...        3890
# 1321400060    2.00        0.00     0          3  ...        1715
#
#             has_basement  sqft_basement  yr_built  yr_renovated  zipcode  \
# id
# 6414100192             1         400.00      1951       1991.00    98125
# 2487200875             1         910.00      1965          0.00    98136
# 1954400510             0           0.00      1987          0.00    98074
# 7237550310             1        1530.00      2001          0.00    98053
# 1321400060             0           0.00      1995          0.00    98003
#
#              lat    long  sqft_living15  sqft_lot15
# id
# 6414100192 47.72 -122.32           1690        7639
# 2487200875 47.52 -122.39           1360        5000
# 1954400510 47.62 -122.05           1800        7503
# 7237550310 47.66 -122.00           4760      101930
# 1321400060 47.31 -122.33           2238        6819
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Year Built

# %%
clean_column('yr_built')

regplot('yr_built')
# Out:
# Datatype: int64
# Total unique itms: 116
# Displaying first 10:
# [1951 1965 1987 2001 1995 1963 1960 2003 1942 1977]
# Minimum value: 1900.  Maximum value: 2015
# count   15809.00
# mean     1971.11
# std        29.33
# min      1900.00
# 25%      1952.00
# 50%      1975.00
# 75%      1997.00
# max      2015.00
# Name: yr_built, dtype: float64
# <AxesSubplot:xlabel='yr_built', ylabel='price'>

# %%
hist('yr_built')

# %% [markdown]
# ## yr_renovated

# %%
clean_column('yr_renovated')

regplot('yr_renovated')
# Out:
# Datatype: float64
# Total unique itms: 70
# Displaying first 10:
# [1991.    0. 2002. 2010. 1992. 2013. 1994. 1978. 2005. 2003.]
# Minimum value: 0.0.  Maximum value: 2015.0
# count   15809.00
# mean       82.32
# std       396.94
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max      2015.00
# Name: yr_renovated, dtype: float64
# <AxesSubplot:xlabel='yr_renovated', ylabel='price'>

# %% [markdown]
# Convert to binary.

# %%
renovated = np.where(df['yr_renovated'] > 0, 1, 0)

df['renovated'] = renovated

del df['yr_renovated']

df.head(5)
# Out:
#                  date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 6414100192 2014-12-09  538000.00         3       2.25         2570      7242
# 2487200875 2014-12-09  604000.00         4       3.00         1960      5000
# 1954400510 2015-02-18  510000.00         3       2.00         1680      8080
# 7237550310 2014-05-12 1230000.00         4       4.50         5420    101930
# 1321400060 2014-06-27  257500.00         3       2.25         1715      6819
#
#             floors  waterfront  view  condition  ...  sqft_above  \
# id                                               ...
# 6414100192    2.00        0.00     0          3  ...        2170
# 2487200875    1.00        0.00     0          5  ...        1050
# 1954400510    1.00        0.00     0          3  ...        1680
# 7237550310    1.00        0.00     0          3  ...        3890
# 1321400060    2.00        0.00     0          3  ...        1715
#
#             has_basement  sqft_basement  yr_built  zipcode   lat    long  \
# id
# 6414100192             1         400.00      1951    98125 47.72 -122.32
# 2487200875             1         910.00      1965    98136 47.52 -122.39
# 1954400510             0           0.00      1987    98074 47.62 -122.05
# 7237550310             1        1530.00      2001    98053 47.66 -122.00
# 1321400060             0           0.00      1995    98003 47.31 -122.33
#
#             sqft_living15  sqft_lot15  renovated
# id
# 6414100192           1690        7639          1
# 2487200875           1360        5000          0
# 1954400510           1800        7503          0
# 7237550310           4760      101930          0
# 1321400060           2238        6819          0
#
# [5 rows x 21 columns]

# %%
df.head()
# Out:
#                  date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 6414100192 2014-12-09  538000.00         3       2.25         2570      7242
# 2487200875 2014-12-09  604000.00         4       3.00         1960      5000
# 1954400510 2015-02-18  510000.00         3       2.00         1680      8080
# 7237550310 2014-05-12 1230000.00         4       4.50         5420    101930
# 1321400060 2014-06-27  257500.00         3       2.25         1715      6819
#
#             floors  waterfront  view  condition  ...  sqft_above  \
# id                                               ...
# 6414100192    2.00        0.00     0          3  ...        2170
# 2487200875    1.00        0.00     0          5  ...        1050
# 1954400510    1.00        0.00     0          3  ...        1680
# 7237550310    1.00        0.00     0          3  ...        3890
# 1321400060    2.00        0.00     0          3  ...        1715
#
#             has_basement  sqft_basement  yr_built  zipcode   lat    long  \
# id
# 6414100192             1         400.00      1951    98125 47.72 -122.32
# 2487200875             1         910.00      1965    98136 47.52 -122.39
# 1954400510             0           0.00      1987    98074 47.62 -122.05
# 7237550310             1        1530.00      2001    98053 47.66 -122.00
# 1321400060             0           0.00      1995    98003 47.31 -122.33
#
#             sqft_living15  sqft_lot15  renovated
# id
# 6414100192           1690        7639          1
# 2487200875           1360        5000          0
# 1954400510           1800        7503          0
# 7237550310           4760      101930          0
# 1321400060           2238        6819          0
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Zipcode

# %%
clean_column('zipcode')
# Out:
# Datatype: int64
# Total unique itms: 70
# Displaying first 10:
# [98125 98136 98074 98053 98003 98198 98146 98038 98115 98107]
# Minimum value: 98001.  Maximum value: 98199
# count   15809.00
# mean    98077.56
# std        53.41
# min     98001.00
# 25%     98033.00
# 50%     98065.00
# 75%     98117.00
# max     98199.00
# Name: zipcode, dtype: float64
# 'zipcode'

# %% [markdown]
# Zipcode should be integer for now, since there will be no decimals.  It might be worth considering conversion to string as well further in the project.

# %%
df['zipcode'] = df['zipcode'].astype(int)

# %%
clean_column('zipcode')

regplot('zipcode')
# Out:
# Datatype: int32
# Total unique itms: 70
# Displaying first 10:
# [98125 98136 98074 98053 98003 98198 98146 98038 98115 98107]
# Minimum value: 98001.  Maximum value: 98199
# count   15809.00
# mean    98077.56
# std        53.41
# min     98001.00
# 25%     98033.00
# 50%     98065.00
# 75%     98117.00
# max     98199.00
# Name: zipcode, dtype: float64
# <AxesSubplot:xlabel='zipcode', ylabel='price'>

# %%
hist('zipcode')

# %% [markdown]
# ## 'sqft_living15'
#
# The square footage of interior housing living space for the nearest 15 neighbors

# %%
clean_column('sqft_living15')

regplot('sqft_living15')
# Out:
# Datatype: int64
# Total unique itms: 694
# Displaying first 10:
# [1690 1360 1800 4760 2238 1650 1780 2390 1330 1370]
# Minimum value: 399.  Maximum value: 6210
# count   15809.00
# mean     1990.39
# std       684.15
# min       399.00
# 25%      1490.00
# 50%      1850.00
# 75%      2370.00
# max      6210.00
# Name: sqft_living15, dtype: float64
# <AxesSubplot:xlabel='sqft_living15', ylabel='price'>

# %%
hist('sqft_living15')

# %% [markdown]
# ## 'sqft_lot15'
#
# The square footage of the land lots of the nearest 15 neighbors

# %%
clean_column('sqft_lot15')

regplot('sqft_lot15')
# Out:
# Datatype: int64
# Total unique itms: 7140
# Displaying first 10:
# [  7639   5000   7503 101930   6819   9711   8113   7570   6000  10208]
# Minimum value: 659.  Maximum value: 871200
# count    15809.00
# mean     12914.69
# std      28012.98
# min        659.00
# 25%       5100.00
# 50%       7620.00
# 75%      10102.00
# max     871200.00
# Name: sqft_lot15, dtype: float64
# <AxesSubplot:xlabel='sqft_lot15', ylabel='price'>

# %%
hist('sqft_lot15')

# %% [markdown]
# # EXPLORE

# %% [markdown]
# Now that we're comfortable that we have quality data, it's time to determine which columns we'll want to analyze for our primary analysis.
#
# First we'll review which columns we have to work with:

# %%
# df.info()

# %% [markdown]
# Based on prior anaysis and scrubbing, we'll categorize our columns into three sections:

# %% [markdown]
# Number based
# -price
# -bedrooms
# -bathrooms
# -sqft_living
# -sqft_lot
# -floors
# -condition
# -grade
# -sqft_above
# -sqft_basement
# -yr_built
# -sqft_living15
# -sqft_lot15
#
#
# Categorical
# -waterfront
#
# Remove from elementary model
# -date
# -zipcode
# -lat
# -long
# -has_basement
# -view

# %% [markdown]
# We have a mix of integers and floats.  Some features like view, condition, and grade represent a rating system.  Since they tend to ascend to higher value, we do not need to make categories.
#
# We will need to make one categorical variable for waterfront, which is represented as a binary 0 or 1.
#
# For this analysis, we will not analyze zipcode, lat, or long, but zip might be interesting for categorical modeling in future analyses.  Date will not be important since all sales were from 2014-2015, and it doesn't really reflect anything meaningful without a much longer time horizon. 'View' will be removed, since we can't find reliable information on what this represents.  Intuitively, we thought it might represent a star ranking for how good the exterior view is, but the description reads "has been viewed."  This might indicate website or in person traffic and could therefore be helpful for future analysis, but since we do not have a clear cut definition, we will remove.

# %%
df.drop(['date', 'lat', 'long', 'view'],axis=1,inplace=True)

# %%
df
# Out:
#                 price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id
# 6414100192  538000.00         3       2.25         2570      7242    2.00
# 2487200875  604000.00         4       3.00         1960      5000    1.00
# 1954400510  510000.00         3       2.00         1680      8080    1.00
# 7237550310 1230000.00         4       4.50         5420    101930    1.00
# 1321400060  257500.00         3       2.25         1715      6819    2.00
# ...               ...       ...        ...          ...       ...     ...
# 2997800021  475000.00         3       2.50         1310      1294    2.00
# 263000018   360000.00         3       2.50         1530      1131    3.00
# 6600060120  400000.00         4       2.50         2310      5813    2.00
# 1523300141  402101.00         2       0.75         1020      1350    2.00
# 1523300157  325000.00         2       0.75         1020      1076    2.00
#
#             waterfront  condition  grade  sqft_above  has_basement  \
# id
# 6414100192        0.00          3      7        2170             1
# 2487200875        0.00          5      7        1050             1
# 1954400510        0.00          3      8        1680             0
# 7237550310        0.00          3     11        3890             1
# 1321400060        0.00          3      7        1715             0
# ...                ...        ...    ...         ...           ...
# 2997800021        0.00          3      8        1180             1
# 263000018         0.00          3      8        1530             0
# 6600060120        0.00          3      8        2310             0
# 1523300141        0.00          3      7        1020             0
# 1523300157        0.00          3      7        1020             0
#
#             sqft_basement  yr_built  zipcode  sqft_living15  sqft_lot15  \
# id
# 6414100192         400.00      1951    98125           1690        7639
# 2487200875         910.00      1965    98136           1360        5000
# 1954400510           0.00      1987    98074           1800        7503
# 7237550310        1530.00      2001    98053           4760      101930
# 1321400060           0.00      1995    98003           2238        6819
# ...                   ...       ...      ...            ...         ...
# 2997800021         130.00      2008    98116           1330        1265
# 263000018            0.00      2009    98103           1530        1509
# 6600060120           0.00      2014    98146           1830        7200
# 1523300141           0.00      2009    98144           1020        2007
# 1523300157           0.00      2008    98144           1020        1357
#
#             renovated
# id
# 6414100192          1
# 2487200875          0
# 1954400510          0
# 7237550310          0
# 1321400060          0
# ...               ...
# 2997800021          0
# 263000018           0
# 6600060120          0
# 1523300141          0
# 1523300157          0
#
# [15809 rows x 17 columns]

# %% [markdown]
# ## Multicollinearity

# %%
def heatmap(df_name, figsize=(15,10), cmap='Reds'):
    corr = df_name.drop('price',axis=1).corr()
    mask = np.zeros_like(corr)
    mask[np.triu_indices_from(mask)] = True
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(corr, annot=True, cmap=cmap, mask=mask)
    return fig, ax

heatmap(df)
# Out:
# (<Figure size 1080x720 with 2 Axes>, <AxesSubplot:>)

# %% [markdown]
# drop:
#
# sqft_above + sqft_basement - these are duplicative of sqft_living.
#
# sqft_lot15 and sqft_living15 - these could be more interesting for broader analysis of areas.  Since there is high multicolinearity, we can save these for when we look at zip, lat, and long.

# %%
del df['sqft_above']
del df['sqft_basement']
del df['sqft_lot15']
del df['sqft_living15']

# %%
heatmap(df)
# Out:
# (<Figure size 1080x720 with 2 Axes>, <AxesSubplot:>)

# %% [markdown]
# If we're defining multicollinear variables as having a correlation of 0.75 and higher, then our only example is sqft_above and grade at 0.76.  We could surmise that that there is a relationship between larger homes and overall grade given between King County grading system.  However, it seems inappropriate to remove grade, since it seems intuitive that there might be some highly graded smaller homes.
#
# We are ready to move to the next step.

# %% [markdown]
# # One Hot Variables

# %%
# https://nbviewer.jupyter.org/github/examsherpa/King-County-Housing-Price-Prediction/blob/main/housing_modeling.ipynb

# dummies = df[]

# df_preprocessed = df.drop(categoricals, axis=1)

# df_preprocessed = pd.concat([df_preprocessed, dummies], axis=1)

# df_preprocessed.head()

# %%
# dummies

# %% [markdown]
# # MODEL

# %% [markdown]
# ## Data Modeling
# Describe and justify the process for analyzing or modeling the data.
#
# ***
# Questions to consider:
# * How did you analyze or model the data?
# * How did you iterate on your initial approach to make it better?
# * Why are these choices appropriate given the data and the business problem?
# ***

# %%
df.head()
# Out:
#                 price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id
# 6414100192  538000.00         3       2.25         2570      7242    2.00
# 2487200875  604000.00         4       3.00         1960      5000    1.00
# 1954400510  510000.00         3       2.00         1680      8080    1.00
# 7237550310 1230000.00         4       4.50         5420    101930    1.00
# 1321400060  257500.00         3       2.25         1715      6819    2.00
#
#             waterfront  condition  grade  has_basement  yr_built  zipcode  \
# id
# 6414100192        0.00          3      7             1      1951    98125
# 2487200875        0.00          5      7             1      1965    98136
# 1954400510        0.00          3      8             0      1987    98074
# 7237550310        0.00          3     11             1      2001    98053
# 1321400060        0.00          3      7             0      1995    98003
#
#             renovated
# id
# 6414100192          1
# 2487200875          0
# 1954400510          0
# 7237550310          0
# 1321400060          0

# %% [markdown]
# ## VIF Multicollinearity Check

# %%
import statsmodels.api as sm
import statsmodels.stats.api as sms
import statsmodels.formula.api as smf

from scipy import stats

# %%
# def make_model(df_name):

#     features = ' + '.join(df_name.drop('price',axis=1).columns)

#     f  = "price~"+features

#     model = smf.ols(f, df_name).fit()
#     display(model.summary())
#     return model
    
# # model(df)

# %%
# from statsmodels.stats.outliers_influence import variance_inflation_factor

# # x_cols = ['bedrooms', 'bathrooms', 'sqft_lot', 'floors', 'waterfront',
# #        'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built']

# x_cols = ['bedrooms', 'bathrooms', 'floors',
#        'waterfront', 'condition', 'grade', 'has_basement',
#        'renovated']

# for col in x_cols:
#     df[col] = (df[col] - df[col].mean())/df[col].std()

# X = df[x_cols]
# vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
# list(zip(x_cols, vif))

# %%
# x_cols = ['price', 'sqft_lot', 'waterfront',
#        'condition', 'sqft_above', 'sqft_basement']

# make_model(df[x_cols])

# %%
# model(df)

# %%
def make_model(df_name):

    features = ' + '.join(df_name.drop('price',axis=1).columns)

    f  = "price~"+features

    model = smf.ols(f, df_name).fit()
    display(model.summary())
    return model
    
model1 = make_model(df)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.651
# Model:                            OLS   Adj. R-squared:                  0.651
# Method:                 Least Squares   F-statistic:                     2457.
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):               0.00
# Time:                        13:28:31   Log-Likelihood:            -2.1697e+05
# No. Observations:               15809   AIC:                         4.340e+05
# Df Residuals:                   15796   BIC:                         4.341e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     3.108e+06   3.69e+06      0.842      0.400   -4.13e+06    1.03e+07
# bedrooms     -4.897e+04   2538.992    -19.285      0.000   -5.39e+04    -4.4e+04
# bathrooms     5.175e+04   4233.565     12.225      0.000    4.35e+04    6.01e+04
# sqft_living    188.5110      3.967     47.519      0.000     180.735     196.287
# sqft_lot        -0.2466      0.043     -5.701      0.000      -0.331      -0.162
# floors        2.307e+04   4411.189      5.231      0.000    1.44e+04    3.17e+04
# waterfront    7.608e+05   2.05e+04     37.133      0.000    7.21e+05    8.01e+05
# condition     1.873e+04   3001.262      6.240      0.000    1.28e+04    2.46e+04
# grade         1.249e+05   2558.315     48.814      0.000     1.2e+05     1.3e+05
# has_basement  7337.7566   4180.315      1.755      0.079    -856.138    1.55e+04
# yr_built     -3789.0221     88.836    -42.652      0.000   -3963.150   -3614.894
# zipcode         35.7222     37.039      0.964      0.335     -36.879     108.323
# renovated     1.937e+04   9429.087      2.054      0.040     887.462    3.79e+04
# ==============================================================================
# Omnibus:                    11990.593   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           866606.579
# Skew:                           3.049   Prob(JB):                         0.00
# Kurtosis:                      38.755   Cond. No.                     2.09e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.09e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# model1.pvalues

# pvals = model1.pvalues

# pvals[pvals > 0.05]
# # pvals[pvals > 0.05].index

# %%
# model1.pvalues

# pvals = model1.pvalues

# pvals[pvals > 0.05].index

# %% [markdown]
# ## Model integer check

# %%
df
# Out:
#                 price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id
# 6414100192  538000.00         3       2.25         2570      7242    2.00
# 2487200875  604000.00         4       3.00         1960      5000    1.00
# 1954400510  510000.00         3       2.00         1680      8080    1.00
# 7237550310 1230000.00         4       4.50         5420    101930    1.00
# 1321400060  257500.00         3       2.25         1715      6819    2.00
# ...               ...       ...        ...          ...       ...     ...
# 2997800021  475000.00         3       2.50         1310      1294    2.00
# 263000018   360000.00         3       2.50         1530      1131    3.00
# 6600060120  400000.00         4       2.50         2310      5813    2.00
# 1523300141  402101.00         2       0.75         1020      1350    2.00
# 1523300157  325000.00         2       0.75         1020      1076    2.00
#
#             waterfront  condition  grade  has_basement  yr_built  zipcode  \
# id
# 6414100192        0.00          3      7             1      1951    98125
# 2487200875        0.00          5      7             1      1965    98136
# 1954400510        0.00          3      8             0      1987    98074
# 7237550310        0.00          3     11             1      2001    98053
# 1321400060        0.00          3      7             0      1995    98003
# ...                ...        ...    ...           ...       ...      ...
# 2997800021        0.00          3      8             1      2008    98116
# 263000018         0.00          3      8             0      2009    98103
# 6600060120        0.00          3      8             0      2014    98146
# 1523300141        0.00          3      7             0      2009    98144
# 1523300157        0.00          3      7             0      2008    98144
#
#             renovated
# id
# 6414100192          1
# 2487200875          0
# 1954400510          0
# 7237550310          0
# 1321400060          0
# ...               ...
# 2997800021          0
# 263000018           0
# 6600060120          0
# 1523300141          0
# 1523300157          0
#
# [15809 rows x 13 columns]

# %% [markdown]
# ## Categorical Variables

# %%
#if majority of zipcodes are not significant, drop whole column and vice versa.

categoricals = ['bedrooms', 
                'bathrooms', 
                'floors', 
                'waterfront', 
                'condition', 
                'grade', 
                'has_basement',
                'zipcode',
                'renovated']

categoricals
# Out:
# ['bedrooms',
#  'bathrooms',
#  'floors',
#  'waterfront',
#  'condition',
#  'grade',
#  'has_basement',
#  'zipcode',
#  'renovated']

# %%
# features = ' + '.join(df.drop('price',axis=1).columns)

# for variable in categoricals:
#     features = features.replace(variable, ("C(" + variable + ")"))
# #     features.replace(variable, ("C(" + variable + ")"))

# features

# %%
# features = ' + '.join(df.drop('price',axis=1).columns)
# features = features.replace("zipcode", "C(zipcode)")
# features

# %%
def feature_reset(df, categoricals):

    features = ' + '.join(df.drop('price',axis=1).columns)

    for variable in categoricals:
        features = features.replace(variable, ("C(" + variable + ")"))
    #     features.replace(variable, ("C(" + variable + ")"))
    return features

def remove

feature_reset(df, categoricals)
# Out:
# 'C(bedrooms) + C(bathrooms) + sqft_living + sqft_lot + C(floors) + C(waterfront) + C(condition) + C(grade) + C(has_basement) + yr_built + C(zipcode) + C(renovated)'

# %%
# f  = "price~"+features

# model = smf.ols(f, df).fit()

# display(model.summary())

# %%
def make_model(df_name, features):
#     feature_reset()
#     features = ' + '.join(df_name.drop('price',axis=1).columns)

    f  = "price~"+features

    model = smf.ols(f, df_name).fit()
    display(model.summary())
    
    sm.graphics.qqplot(model.resid, stats.norm, fit=True, line="45");
    
    return model
    
model1 = make_model(df, features)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.834
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     611.8
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):               0.00
# Time:                        12:38:15   Log-Likelihood:            -2.1108e+05
# No. Observations:               15809   AIC:                         4.224e+05
# Df Residuals:                   15679   BIC:                         4.234e+05
# Df Model:                         129
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept             5.931e+05   2.37e+05      2.499      0.012    1.28e+05    1.06e+06
# C(bedrooms)[T.2]      1.276e+04    1.4e+04      0.910      0.363   -1.47e+04    4.03e+04
# C(bedrooms)[T.3]      1.667e+04   1.41e+04      1.185      0.236   -1.09e+04    4.42e+04
# C(bedrooms)[T.4]     -3259.9352   1.44e+04     -0.227      0.820   -3.14e+04    2.49e+04
# C(bedrooms)[T.5]     -2.362e+04   1.51e+04     -1.563      0.118   -5.32e+04    5994.927
# C(bedrooms)[T.6]     -4.755e+04   1.84e+04     -2.587      0.010   -8.36e+04   -1.15e+04
# C(bedrooms)[T.7]       -1.7e+05   3.63e+04     -4.689      0.000   -2.41e+05   -9.89e+04
# C(bedrooms)[T.8]     -6.514e+04   5.19e+04     -1.256      0.209   -1.67e+05    3.65e+04
# C(bedrooms)[T.9]      -2.08e+05   7.12e+04     -2.922      0.003   -3.47e+05   -6.84e+04
# C(bedrooms)[T.10]    -3.143e+05   9.11e+04     -3.448      0.001   -4.93e+05   -1.36e+05
# C(bathrooms)[T.0.75]  1.967e+04   9.13e+04      0.215      0.829   -1.59e+05    1.99e+05
# C(bathrooms)[T.1.0]   5.082e+04   8.86e+04      0.573      0.566   -1.23e+05    2.25e+05
# C(bathrooms)[T.1.25]  -4.47e+04   1.09e+05     -0.412      0.680   -2.57e+05    1.68e+05
# C(bathrooms)[T.1.5]   4.366e+04   8.88e+04      0.492      0.623    -1.3e+05    2.18e+05
# C(bathrooms)[T.1.75]  4.529e+04   8.87e+04      0.510      0.610   -1.29e+05    2.19e+05
# C(bathrooms)[T.2.0]    4.16e+04   8.88e+04      0.469      0.639   -1.32e+05    2.16e+05
# C(bathrooms)[T.2.25]   6.05e+04   8.88e+04      0.681      0.496   -1.14e+05    2.35e+05
# C(bathrooms)[T.2.5]   5.405e+04   8.88e+04      0.609      0.543    -1.2e+05    2.28e+05
# C(bathrooms)[T.2.75]  5.406e+04   8.89e+04      0.608      0.543    -1.2e+05    2.28e+05
# C(bathrooms)[T.3.0]   6.205e+04    8.9e+04      0.697      0.486   -1.12e+05    2.37e+05
# C(bathrooms)[T.3.25]   1.11e+05   8.92e+04      1.245      0.213   -6.38e+04    2.86e+05
# C(bathrooms)[T.3.5]    7.36e+04   8.91e+04      0.826      0.409   -1.01e+05    2.48e+05
# C(bathrooms)[T.3.75]   1.58e+05   9.02e+04      1.751      0.080   -1.88e+04    3.35e+05
# C(bathrooms)[T.4.0]   1.736e+05   9.03e+04      1.923      0.055   -3395.730    3.51e+05
# C(bathrooms)[T.4.25]  2.404e+05   9.12e+04      2.636      0.008    6.16e+04    4.19e+05
# C(bathrooms)[T.4.5]   1.892e+05   9.09e+04      2.083      0.037    1.11e+04    3.67e+05
# C(bathrooms)[T.4.75]  5.094e+05   9.69e+04      5.259      0.000     3.2e+05    6.99e+05
# C(bathrooms)[T.5.0]    3.84e+05   9.83e+04      3.908      0.000    1.91e+05    5.77e+05
# C(bathrooms)[T.5.25]  2.321e+05   1.01e+05      2.300      0.021    3.43e+04     4.3e+05
# C(bathrooms)[T.5.5]   5.884e+05   1.06e+05      5.573      0.000    3.81e+05    7.95e+05
# C(bathrooms)[T.5.75] -8.698e+04   1.42e+05     -0.614      0.539   -3.64e+05     1.9e+05
# C(bathrooms)[T.6.0]   7.187e+05   1.11e+05      6.495      0.000    5.02e+05    9.36e+05
# C(bathrooms)[T.6.75]   1.03e+06    1.8e+05      5.731      0.000    6.77e+05    1.38e+06
# C(bathrooms)[T.7.5]  -1.638e+05    1.9e+05     -0.860      0.390   -5.37e+05     2.1e+05
# C(bathrooms)[T.7.75]  2.836e+06   1.87e+05     15.151      0.000    2.47e+06     3.2e+06
# C(bathrooms)[T.8.0]   1.572e+06   1.47e+05     10.729      0.000    1.29e+06    1.86e+06
# C(floors)[T.1.5]     -9171.2970   4980.093     -1.842      0.066   -1.89e+04     590.259
# C(floors)[T.2.0]     -1.913e+04   4127.541     -4.635      0.000   -2.72e+04    -1.1e+04
# C(floors)[T.2.5]      4.864e+04   1.49e+04      3.257      0.001    1.94e+04    7.79e+04
# C(floors)[T.3.0]     -7.099e+04   9361.929     -7.583      0.000   -8.93e+04   -5.26e+04
# C(floors)[T.3.5]      1.025e+04   6.35e+04      0.161      0.872   -1.14e+05    1.35e+05
# C(waterfront)[T.1.0]  8.281e+05   1.47e+04     56.359      0.000    7.99e+05    8.57e+05
# C(condition)[T.2]     5.332e+04   3.77e+04      1.413      0.158   -2.07e+04    1.27e+05
# C(condition)[T.3]     6.883e+04   3.55e+04      1.938      0.053    -782.643    1.38e+05
# C(condition)[T.4]     9.643e+04   3.55e+04      2.715      0.007    2.68e+04    1.66e+05
# C(condition)[T.5]     1.375e+05   3.57e+04      3.850      0.000    6.75e+04    2.07e+05
# C(grade)[T.4]        -1.089e+05   1.59e+05     -0.686      0.492    -4.2e+05    2.02e+05
# C(grade)[T.5]        -1.731e+05   1.56e+05     -1.113      0.266   -4.78e+05    1.32e+05
# C(grade)[T.6]        -1.809e+05   1.55e+05     -1.164      0.244   -4.85e+05    1.24e+05
# C(grade)[T.7]        -1.672e+05   1.55e+05     -1.076      0.282   -4.72e+05    1.37e+05
# C(grade)[T.8]        -1.266e+05   1.55e+05     -0.814      0.415   -4.31e+05    1.78e+05
# C(grade)[T.9]        -3.668e+04   1.56e+05     -0.236      0.814   -3.42e+05    2.68e+05
# C(grade)[T.10]        9.149e+04   1.56e+05      0.588      0.557   -2.14e+05    3.97e+05
# C(grade)[T.11]        2.529e+05   1.56e+05      1.621      0.105   -5.28e+04    5.59e+05
# C(grade)[T.12]        6.661e+05   1.57e+05      4.239      0.000    3.58e+05    9.74e+05
# C(grade)[T.13]        1.305e+06   1.64e+05      7.943      0.000    9.83e+05    1.63e+06
# C(has_basement)[T.1]  -2.57e+04   3267.481     -7.865      0.000   -3.21e+04   -1.93e+04
# C(zipcode)[T.98002]   1920.3942   1.58e+04      0.121      0.903   -2.91e+04    3.29e+04
# C(zipcode)[T.98003]  -5607.4049   1.41e+04     -0.397      0.692   -3.33e+04    2.21e+04
# C(zipcode)[T.98004]    7.53e+05   1.41e+04     53.368      0.000    7.25e+05    7.81e+05
# C(zipcode)[T.98005]    2.95e+05   1.67e+04     17.650      0.000    2.62e+05    3.28e+05
# C(zipcode)[T.98006]   2.571e+05   1.27e+04     20.177      0.000    2.32e+05    2.82e+05
# C(zipcode)[T.98007]   2.438e+05   1.81e+04     13.487      0.000    2.08e+05    2.79e+05
# C(zipcode)[T.98008]   2.714e+05   1.43e+04     19.027      0.000    2.43e+05    2.99e+05
# C(zipcode)[T.98010]   4.712e+04   2.07e+04      2.273      0.023    6492.128    8.77e+04
# C(zipcode)[T.98011]   1.322e+05   1.61e+04      8.210      0.000    1.01e+05    1.64e+05
# C(zipcode)[T.98014]    8.59e+04   1.88e+04      4.563      0.000     4.9e+04    1.23e+05
# C(zipcode)[T.98019]    8.74e+04   1.66e+04      5.259      0.000    5.48e+04     1.2e+05
# C(zipcode)[T.98022]   9280.9004   1.53e+04      0.608      0.543   -2.07e+04    3.92e+04
# C(zipcode)[T.98023]  -2.891e+04   1.25e+04     -2.319      0.020   -5.33e+04   -4477.873
# C(zipcode)[T.98024]   1.407e+05   2.23e+04      6.316      0.000     9.7e+04    1.84e+05
# C(zipcode)[T.98027]   1.589e+05    1.3e+04     12.176      0.000    1.33e+05    1.84e+05
# C(zipcode)[T.98028]   1.303e+05   1.42e+04      9.164      0.000    1.02e+05    1.58e+05
# C(zipcode)[T.98029]    2.07e+05   1.38e+04     15.044      0.000     1.8e+05    2.34e+05
# C(zipcode)[T.98030]   2303.3020   1.47e+04      0.156      0.876   -2.66e+04    3.12e+04
# C(zipcode)[T.98031]   1.269e+04   1.44e+04      0.882      0.378   -1.55e+04    4.09e+04
# C(zipcode)[T.98032]  -3754.5868   1.81e+04     -0.208      0.836   -3.92e+04    3.17e+04
# C(zipcode)[T.98033]   3.574e+05   1.29e+04     27.664      0.000    3.32e+05    3.83e+05
# C(zipcode)[T.98034]   2.086e+05   1.23e+04     16.977      0.000    1.85e+05    2.33e+05
# C(zipcode)[T.98038]   3.764e+04   1.21e+04      3.118      0.002     1.4e+04    6.13e+04
# C(zipcode)[T.98039]   1.171e+06    2.8e+04     41.842      0.000    1.12e+06    1.23e+06
# C(zipcode)[T.98040]   5.049e+05   1.47e+04     34.444      0.000    4.76e+05    5.34e+05
# C(zipcode)[T.98042]   1733.7621   1.22e+04      0.142      0.887   -2.22e+04    2.56e+04
# C(zipcode)[T.98045]   1.018e+05   1.54e+04      6.607      0.000    7.16e+04    1.32e+05
# C(zipcode)[T.98052]   2.389e+05   1.22e+04     19.555      0.000    2.15e+05    2.63e+05
# C(zipcode)[T.98053]    2.06e+05   1.32e+04     15.585      0.000     1.8e+05    2.32e+05
# C(zipcode)[T.98055]   4.047e+04   1.45e+04      2.795      0.005    1.21e+04    6.89e+04
# C(zipcode)[T.98056]   9.162e+04    1.3e+04      7.051      0.000    6.62e+04    1.17e+05
# C(zipcode)[T.98058]   2.503e+04   1.28e+04      1.958      0.050     -25.539    5.01e+04
# C(zipcode)[T.98059]   8.497e+04   1.28e+04      6.641      0.000    5.99e+04     1.1e+05
# C(zipcode)[T.98065]   1.081e+05   1.41e+04      7.670      0.000    8.05e+04    1.36e+05
# C(zipcode)[T.98070]  -3808.2445   1.93e+04     -0.197      0.844   -4.17e+04    3.41e+04
# C(zipcode)[T.98072]    1.52e+05   1.44e+04     10.557      0.000    1.24e+05     1.8e+05
# C(zipcode)[T.98074]    1.75e+05   1.31e+04     13.358      0.000    1.49e+05    2.01e+05
# C(zipcode)[T.98075]   1.731e+05   1.36e+04     12.753      0.000    1.47e+05       2e+05
# C(zipcode)[T.98077]   1.125e+05   1.57e+04      7.151      0.000    8.17e+04    1.43e+05
# C(zipcode)[T.98092]  -2.352e+04   1.35e+04     -1.744      0.081   -4.99e+04    2907.198
# C(zipcode)[T.98102]   4.956e+05   2.19e+04     22.600      0.000    4.53e+05    5.39e+05
# C(zipcode)[T.98103]   3.358e+05   1.27e+04     26.417      0.000    3.11e+05    3.61e+05
# C(zipcode)[T.98105]   4.757e+05   1.56e+04     30.476      0.000    4.45e+05    5.06e+05
# C(zipcode)[T.98106]   1.233e+05    1.4e+04      8.808      0.000    9.59e+04    1.51e+05
# C(zipcode)[T.98107]   3.579e+05   1.47e+04     24.282      0.000    3.29e+05    3.87e+05
# C(zipcode)[T.98108]    1.17e+05   1.65e+04      7.112      0.000    8.48e+04    1.49e+05
# C(zipcode)[T.98109]   4.756e+05   2.05e+04     23.254      0.000    4.35e+05    5.16e+05
# C(zipcode)[T.98112]   6.262e+05   1.49e+04     41.902      0.000    5.97e+05    6.56e+05
# C(zipcode)[T.98115]   3.457e+05   1.25e+04     27.616      0.000    3.21e+05     3.7e+05
# C(zipcode)[T.98116]   3.116e+05   1.39e+04     22.435      0.000    2.84e+05    3.39e+05
# C(zipcode)[T.98117]   3.223e+05   1.26e+04     25.608      0.000    2.98e+05    3.47e+05
# C(zipcode)[T.98118]   1.712e+05   1.27e+04     13.496      0.000    1.46e+05    1.96e+05
# C(zipcode)[T.98119]   5.059e+05   1.69e+04     29.943      0.000    4.73e+05    5.39e+05
# C(zipcode)[T.98122]   3.328e+05   1.48e+04     22.540      0.000    3.04e+05    3.62e+05
# C(zipcode)[T.98125]    2.04e+05   1.32e+04     15.481      0.000    1.78e+05     2.3e+05
# C(zipcode)[T.98126]   2.034e+05   1.38e+04     14.726      0.000    1.76e+05     2.3e+05
# C(zipcode)[T.98133]   1.562e+05   1.27e+04     12.269      0.000    1.31e+05    1.81e+05
# C(zipcode)[T.98136]   2.696e+05   1.47e+04     18.310      0.000    2.41e+05    2.98e+05
# C(zipcode)[T.98144]   2.928e+05   1.38e+04     21.176      0.000    2.66e+05     3.2e+05
# C(zipcode)[T.98146]   9.699e+04   1.43e+04      6.802      0.000     6.9e+04    1.25e+05
# C(zipcode)[T.98148]    5.33e+04   2.55e+04      2.089      0.037    3282.249    1.03e+05
# C(zipcode)[T.98155]   1.417e+05    1.3e+04     10.925      0.000    1.16e+05    1.67e+05
# C(zipcode)[T.98166]   7.342e+04   1.49e+04      4.937      0.000    4.43e+04    1.03e+05
# C(zipcode)[T.98168]   4.644e+04   1.47e+04      3.158      0.002    1.76e+04    7.53e+04
# C(zipcode)[T.98177]   2.555e+05   1.49e+04     17.189      0.000    2.26e+05    2.85e+05
# C(zipcode)[T.98178]   4.472e+04   1.48e+04      3.017      0.003    1.57e+04    7.38e+04
# C(zipcode)[T.98188]   2.814e+04   1.83e+04      1.540      0.124   -7681.504     6.4e+04
# C(zipcode)[T.98198]   2.065e+04   1.44e+04      1.438      0.151   -7504.350    4.88e+04
# C(zipcode)[T.98199]   4.017e+05   1.44e+04     27.971      0.000    3.74e+05     4.3e+05
# C(renovated)[T.1]     5.915e+04   6689.572      8.842      0.000     4.6e+04    7.23e+04
# sqft_living            162.9652      3.085     52.825      0.000     156.918     169.012
# sqft_lot                 0.1897      0.032      5.864      0.000       0.126       0.253
# yr_built              -304.5310     79.374     -3.837      0.000    -460.113    -148.949
# ==============================================================================
# Omnibus:                    10871.320   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1175628.685
# Skew:                           2.474   Prob(JB):                         0.00
# Kurtosis:                      44.955   Cond. No.                     1.91e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.91e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
categoricals = ['floors', 
                'waterfront', 
                'condition',  
                'has_basement',
                'zipcode',
                'renovated']

categoricals
# Out:
# ['floors', 'waterfront', 'condition', 'has_basement', 'zipcode', 'renovated']

# %%
df = df.drop(['bedrooms', 'bathrooms', 'grade'], axis=1)

df.head()
# Out:
#                 price  sqft_living  sqft_lot  floors  waterfront  condition  \
# id
# 6414100192  538000.00         2570      7242    2.00        0.00          3
# 2487200875  604000.00         1960      5000    1.00        0.00          5
# 1954400510  510000.00         1680      8080    1.00        0.00          3
# 7237550310 1230000.00         5420    101930    1.00        0.00          3
# 1321400060  257500.00         1715      6819    2.00        0.00          3
#
#             has_basement  yr_built  zipcode  renovated
# id
# 6414100192             1      1951    98125          1
# 2487200875             1      1965    98136          0
# 1954400510             0      1987    98074          0
# 7237550310             1      2001    98053          0
# 1321400060             0      1995    98003          0

# %%
def feature_reset(df, categoricals):

    features = ' + '.join(df.drop('price',axis=1).columns)

    for variable in categoricals:
        features = features.replace(variable, ("C(" + variable + ")"))
    #     features.replace(variable, ("C(" + variable + ")"))
    return features

feature_reset()
# Out:
# 'sqft_living + sqft_lot + C(floors) + C(waterfront) + C(condition) + C(has_basement) + yr_built + C(zipcode) + C(renovated)'

# %%
feature_reset()
# Out:
# 'bedrooms + bathrooms + sqft_living + sqft_lot + C(floors) + C(waterfront) + C(condition) + grade + C(has_basement) + yr_built + C(zipcode) + C(renovated)'

# %% [markdown]
# ## Refining based on P-values

# %%
model1.pvalues

pvals = model1.pvalues

pvals[pvals > 0.05]
# pvals[pvals > 0.05].index

# %% [markdown]
# It seems that certain bedroom numbers don't have a significant effect.  Bathrooms have very little effect.  1.5 and 3.5 floors might not have an effect, likely due to low representaion in dataset.  Some conditions seems important, grade seems negligible, and a 12 of the 69 zip codes can be removed.
#
# We will remove the following columns:
#
# bedrooms
#
# bathrooms
#
# grade

# %%
df_model = df.copy()

# %%
df = df.drop(['bedrooms', 'bathrooms', 'grade'], axis=1)

df.head()

# %%
#if majority of zipcodes are not significant, drop whole column and vice versa.

categoricals = ['floors', 
                'waterfront', 
                'condition',
                'has_basement',
                'zipcode',
                'renovated']

features

# %%
feature_reset(df, categoricals)

# features = ' + '.join(df.drop('price',axis=1).columns)

# for variable in categoricals:
#     features = features.replace(variable, ("C(" + variable + ")"))

# features

# %%
model2 = make_model(df, features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\patsy\compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\patsy\eval.py in eval(self, expr, source_name, inner_namespace)
#     164         code = compile(expr, source_name, "eval", self.flags, False)
# --> 165         return eval(code, {}, VarLookupDict([inner_namespace]
#     166                                             + self._namespaces))
#
# <string> in <module>
#
# NameError: name 'bathrooms' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-701-5716d0a890e0> in <module>
# ----> 1 model2 = make_model(df, features)
#
# <ipython-input-692-52ffd89056cd> in make_model(df_name, features)
#       5     f  = "price~"+features
#       6
# ----> 7     model = smf.ols(f, df_name).fit()
#       8     display(model.summary())
#       9
#
# ~\anaconda3\envs\learn-env\lib\site-packages\statsmodels\base\model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     167             missing = 'raise'
#     168
# --> 169         tmp = handle_formula_data(data, None, formula, depth=eval_env,
#     170                                   missing=missing)
#     171         ((endog, exog), missing_idx, design_info) = tmp
#
# ~\anaconda3\envs\learn-env\lib\site-packages\statsmodels\formula\formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      61     else:
#      62         if data_util._is_using_pandas(Y, None):
# ---> 63             result = dmatrices(formula, Y, depth, return_type='dataframe',
#      64                                NA_action=na_action)
#      65         else:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\patsy\highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     307     """
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#     310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\patsy\highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     162     def data_iter_maker():
#     163         return iter([data])
# --> 164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
#     165                                       NA_action)
#     166     if design_infos is not None:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\patsy\highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      64     if isinstance(formula_like, ModelDesc):
#      65         assert isinstance(eval_env, EvalEnvironment)
# ---> 66         return design_matrix_builders([formula_like.lhs_termlist,
#      67                                        formula_like.rhs_termlist],
#      68                                       data_iter_maker,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\patsy\build.py in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     691     # on some data to find out what type of data they return.
#     692     (num_column_counts,
# --> 693      cat_levels_contrasts) = _examine_factor_types(all_factors,
#     694                                                    factor_states,
#     695                                                    data_iter_maker,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\patsy\build.py in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     441     for data in data_iter_maker():
#     442         for factor in list(examine_needed):
# --> 443             value = factor.eval(factor_states[factor], data)
#     444             if factor in cat_sniffers or guess_categorical(value):
#     445                 if factor not in cat_sniffers:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\patsy\eval.py in eval(self, memorize_state, data)
#     562
#     563     def eval(self, memorize_state, data):
# --> 564         return self._eval(memorize_state["eval_code"],
#     565                           memorize_state,
#     566                           data)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\patsy\eval.py in _eval(self, code, memorize_state, data)
#     545     def _eval(self, code, memorize_state, data):
#     546         inner_namespace = VarLookupDict([data, memorize_state["transforms"]])
# --> 547         return call_and_wrap_exc("Error evaluating factor",
#     548                                  self,
#     549                                  memorize_state["eval_env"].eval,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\patsy\compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      41                                  origin)
#      42             # Use 'exec' to hide this syntax from the Python 2 parser:
# ---> 43             exec("raise new_exc from e")
#      44         else:
#      45             # In python 2, we just let the original exception escape -- better
#
# ~\anaconda3\envs\learn-env\lib\site-packages\patsy\compat.py in <module>
#
# PatsyError: Error evaluating factor: NameError: name 'bathrooms' is not defined
#     price~C(bedrooms) + C(bathrooms) + sqft_living + sqft_lot + C(floors) + C(waterfront) + C(condition) + C(grade) + C(has_basement) + yr_built + C(zipcode) + C(renovated)
#                         ^^^^^^^^^^^^

# %% [markdown]
# ### python remove outliers, z score and iqr method.  we might use IQR.  check price first.

# %% [markdown]
# ### p values - scale all values before running model.  multivariate - Feature Scaling and Normalization

# %% [markdown]
# ### all values before standardizing or scaling or whatever are actually in dollars

# %% [markdown]
# ### removing outliers

# %%
column = 'price'

describe = df.describe()[column]

# %%
describe

q1 = describe['25%']
q3 = describe['75%']

# %%
iqr = q3 - q1

# %%
#anything above q3 + 1.5*IQR

# %%
outlier_index = (df[column] > (q3 + 1.5 * iqr)) | (df[column] < (q1 - 1.5 * iqr))

# %%
df[~outlier_index]
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id
# 6414100192 538000.00     -0.42       0.17         2570      7242    0.94
# 2487200875 604000.00      0.69       1.15         1960      5000   -0.92
# 1954400510 510000.00     -0.42      -0.16         1680      8080   -0.92
# 1321400060 257500.00     -0.42       0.17         1715      6819    0.94
# 2008000270 291850.00     -0.42      -0.81         1060      9711   -0.92
# ...              ...       ...        ...          ...       ...     ...
# 2997800021 475000.00     -0.42       0.49         1310      1294    0.94
# 263000018  360000.00     -0.42       0.49         1530      1131    2.79
# 6600060120 400000.00      0.69       0.49         2310      5813    0.94
# 1523300141 402101.00     -1.52      -1.79         1020      1350    0.94
# 1523300157 325000.00     -1.52      -1.79         1020      1076    0.94
#
#             waterfront  condition  grade  has_basement  yr_built  zipcode  \
# id
# 6414100192       -0.09      -0.63  -0.57          1.24      1951    98125
# 2487200875       -0.09       2.44  -0.57          1.24      1965    98136
# 1954400510       -0.09      -0.63   0.29         -0.80      1987    98074
# 1321400060       -0.09      -0.63  -0.57         -0.80      1995    98003
# 2008000270       -0.09      -0.63  -0.57         -0.80      1963    98198
# ...                ...        ...    ...           ...       ...      ...
# 2997800021       -0.09      -0.63   0.29          1.24      2008    98116
# 263000018        -0.09      -0.63   0.29         -0.80      2009    98103
# 6600060120       -0.09      -0.63   0.29         -0.80      2014    98146
# 1523300141       -0.09      -0.63  -0.57         -0.80      2009    98144
# 1523300157       -0.09      -0.63  -0.57         -0.80      2008    98144
#
#             renovated
# id
# 6414100192       4.82
# 2487200875      -0.21
# 1954400510      -0.21
# 1321400060      -0.21
# 2008000270      -0.21
# ...               ...
# 2997800021      -0.21
# 263000018       -0.21
# 6600060120      -0.21
# 1523300141      -0.21
# 1523300157      -0.21
#
# [14959 rows x 13 columns]

# %%
regplot('sqft_living', df=df)
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
regplot('sqft_living', df=df[~outlier_index])
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
model = make_model(df[~outlier_index])
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.567
# Model:                            OLS   Adj. R-squared:                  0.566
# Method:                 Least Squares   F-statistic:                     1629.
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):               0.00
# Time:                        10:03:38   Log-Likelihood:            -1.9811e+05
# No. Observations:               14959   AIC:                         3.962e+05
# Df Residuals:                   14946   BIC:                         3.963e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept    -4.602e+06   2.35e+06     -1.959      0.050   -9.21e+06    3040.474
# bedrooms     -1.516e+04   1499.674    -10.107      0.000   -1.81e+04   -1.22e+04
# bathrooms     1.822e+04   2125.311      8.572      0.000    1.41e+04    2.24e+04
# sqft_living     89.6858      2.743     32.700      0.000      84.310      95.062
# sqft_lot         0.0694      0.028      2.458      0.014       0.014       0.125
# floors        2.427e+04   1536.073     15.802      0.000    2.13e+04    2.73e+04
# waterfront    1.405e+04   1826.226      7.695      0.000    1.05e+04    1.76e+04
# condition     1.173e+04   1246.939      9.404      0.000    9282.287    1.42e+04
# grade         1.188e+05   1986.712     59.776      0.000    1.15e+05    1.23e+05
# has_basement  1.233e+04   1306.998      9.435      0.000    9770.042    1.49e+04
# yr_built     -2524.6189     58.261    -43.333      0.000   -2638.817   -2410.420
# zipcode        100.8588     23.566      4.280      0.000      54.666     147.051
# renovated     2348.2904   1249.027      1.880      0.060     -99.956    4796.536
# ==============================================================================
# Omnibus:                      617.596   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              857.247
# Skew:                           0.413   Prob(JB):                    7.10e-187
# Kurtosis:                       3.832   Cond. No.                     2.09e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.09e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
y_hat = model1.predict(df)

y = df['price']

resid = y - y_hat

# %%
y_hat.shape, model.resid.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-305-51ab711f5f73> in <module>
# ----> 1 y_hat.shape, model.resid.shape
#
# NameError: name 'model' is not defined

# %%
plt.scatter(x=y_hat, y=resid)
plt.axhline(0)

# %% [markdown]
# # iNTERPRET

# %% [markdown]
# Evaluate how well your work solves the stated business problem.
#
# ***
# Questions to consider:
# * How do you interpret the results?
# * How well does your model fit your data? How much better is this than your baseline model?
# * How confident are you that your results would generalize beyond the data you have?
# * How confident are you that this model would benefit the business if put into use?
# ***

# %% [markdown]
# # CONCLUSIONS & RECOMMENDATIONS

# %% [markdown]
# Provide your conclusions about the work you've done, including any limitations or next steps.
#
# ***
# Questions to consider:
# * What would you recommend the business do as a result of this work?
# * What are some reasons why your analysis might not fully solve the business problem?
# * What else could you do in the future to improve this project?
# ***

# %% [markdown]
# # Scratch

# %% [markdown]
# ## Log transform

# %%
plt.style.use('seaborn')

fig, axes = plt.subplots(nrows=(df.shape[1] // 3 + 1), ncols=3, figsize=(16,16))

categoricals = [column for column in df.columns if column != 'Id']

for col, ax in zip(categoricals, axes.flatten()):
    ax.hist(df[col], bins='auto')
    ax.set_title(col)
    
fig.tight_layout()

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_lot', 'floors', 'waterfront',
#        'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built'],
#       dtype='object')

# %% [markdown]
# remove waterfront, sqft_basement

# %%
df_log = df.copy()

df_log.head()
# Out:
#                price  bedrooms  bathrooms  sqft_lot  floors  waterfront  \
# id
# 7129300520 221900.00         3       1.00      5650    1.00           0
# 6414100192 538000.00         3       2.25      7242    2.00           0
# 5631500400 180000.00         2       1.00     10000    1.00           0
# 2487200875 604000.00         4       3.00      5000    1.00           0
# 1954400510 510000.00         3       2.00      8080    1.00           0
#
#             condition  grade  sqft_above  sqft_basement  yr_built
# id
# 7129300520          3      7        1180           0.00      1955
# 6414100192          3      7        2170         400.00      1951
# 5631500400          3      6         770           0.00      1933
# 2487200875          5      7        1050         910.00      1965
# 1954400510          3      8        1680           0.00      1987

# %%
log_list = ['price', 'bedrooms', 'bathrooms', 'sqft_lot', 'floors',
    'condition', 'grade', 'sqft_above', 'yr_built']

# waterfront nad sqft_basement removed

# %%
df_log = pd.DataFrame([])

for column in log_list:
    df_log[column] = np.log(df[column])
    
df_log.head()
# Out:
#             price  bedrooms  bathrooms  sqft_lot  floors  condition  grade  \
# id
# 7129300520  12.31      1.10       0.00      8.64    0.00       1.10   1.95
# 6414100192  13.20      1.10       0.81      8.89    0.69       1.10   1.95
# 5631500400  12.10      0.69       0.00      9.21    0.00       1.10   1.79
# 2487200875  13.31      1.39       1.10      8.52    0.00       1.61   1.95
# 1954400510  13.14      1.10       0.69      9.00    0.00       1.10   2.08
#
#             sqft_above  yr_built
# id
# 7129300520        7.07      7.58
# 6414100192        7.68      7.58
# 5631500400        6.65      7.57
# 2487200875        6.96      7.58
# 1954400510        7.43      7.59

# %%
features = ' + '.join(df_log.drop('price',axis=1).columns)

## Create the final formula and create the model
f  = "price~"+features

model = smf.ols(f, df_log).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.606
# Method:                 Least Squares   F-statistic:                     4156.
# Date:                Mon, 12 Apr 2021   Prob (F-statistic):               0.00
# Time:                        12:51:09   Log-Likelihood:                -6725.0
# No. Observations:               21597   AIC:                         1.347e+04
# Df Residuals:                   21588   BIC:                         1.354e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    110.0014      1.482     74.233      0.000     107.097     112.906
# bedrooms      -0.0833      0.010     -8.130      0.000      -0.103      -0.063
# bathrooms      0.2943      0.009     31.644      0.000       0.276       0.312
# sqft_lot      -0.0245      0.003     -7.937      0.000      -0.031      -0.018
# floors        -0.0003      0.010     -0.030      0.976      -0.019       0.018
# condition      0.1365      0.013     10.156      0.000       0.110       0.163
# grade          2.1395      0.024     89.980      0.000       2.093       2.186
# sqft_above     0.2543      0.011     23.493      0.000       0.233       0.276
# yr_built     -13.6052      0.196    -69.579      0.000     -13.988     -13.222
# ==============================================================================
# Omnibus:                      183.559   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              280.802
# Skew:                           0.067   Prob(JB):                     1.06e-61
# Kurtosis:                       3.542   Cond. No.                     9.45e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.45e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df_test = df.drop(['waterfront', 'sqft_basement'], axis=1)

features = ' + '.join(df_test.drop('price',axis=1).columns)

## Create the final formula and create the model
f  = "price~"+features

model = smf.ols(f, df_test).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.586
# Model:                            OLS   Adj. R-squared:                  0.586
# Method:                 Least Squares   F-statistic:                     3821.
# Date:                Mon, 12 Apr 2021   Prob (F-statistic):               0.00
# Time:                        12:53:44   Log-Likelihood:            -2.9786e+05
# No. Observations:               21597   AIC:                         5.957e+05
# Df Residuals:                   21588   BIC:                         5.958e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   8.012e+06   1.39e+05     57.526      0.000    7.74e+06    8.29e+06
# bedrooms   -2.829e+04   2223.286    -12.726      0.000   -3.27e+04   -2.39e+04
# bathrooms     1.2e+05   3423.275     35.051      0.000    1.13e+05    1.27e+05
# sqft_lot      -0.1608      0.040     -4.023      0.000      -0.239      -0.082
# floors     -2.752e+04   3855.794     -7.137      0.000   -3.51e+04      -2e+04
# condition    2.42e+04   2691.502      8.991      0.000    1.89e+04    2.95e+04
# grade       1.633e+05   2230.767     73.196      0.000    1.59e+05    1.68e+05
# sqft_above   115.9552      3.477     33.350      0.000     109.140     122.770
# yr_built   -4630.8434     70.936    -65.282      0.000   -4769.883   -4491.803
# ==============================================================================
# Omnibus:                    18447.974   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1566139.504
# Skew:                           3.657   Prob(JB):                         0.00
# Kurtosis:                      44.072   Cond. No.                     3.82e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.82e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df_log.concat(df.drop(log_list, axis=1), axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-200-307951260388> in <module>
# ----> 1 df_log.concat(df.drop(log_list, axis=1), axis=1)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
pd.concat(df_log, df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-202-c72563b36daa> in <module>
# ----> 1 pd.concat(df_log, df)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     272     ValueError: Indexes have overlapping values: ['a']
#     273     """
# --> 274     op = _Concatenator(
#     275         objs,
#     276         axis=axis,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     307     ):
#     308         if isinstance(objs, (ABCSeries, ABCDataFrame, str)):
# --> 309             raise TypeError(
#     310                 "first argument must be an iterable of pandas "
#     311                 f'objects, you passed an object of type "{type(objs).__name__}"'
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "DataFrame"

# %%
#model discarded 4/19, 10:27am

def make_model(df_name):

    features = ' + '.join(df_name.drop('price',axis=1).columns)

    f  = "price~"+features

    model = smf.ols(f, df_name).fit()
    display(model.summary())
    
    sm.graphics.qqplot(model.resid, stats.norm, fit=True, line="45");
    
    return model
    
model1 = make_model(df)
